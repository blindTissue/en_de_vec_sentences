# %%
from gensim.models import Word2Vec
import os
import numpy as np
english_model = Word2Vec.load(os.path.join('data', 'english_model_lemmatized'))
german_model = Word2Vec.load(os.path.join('data', 'german_model_lemmatized'))

# %%
from copy import deepcopy
def w2v_to_numpy(model):
    """ Convert the word2vec model (the embeddings) into numpy arrays.
    Also create and return the mapping of words to the row numbers.

    Parameters:
    ===========
    model (gensim.Word2Vec): a trained gensim model

    Returns:
    ========
    embeddings (numpy.ndarray): Embeddings of each word
    idx, iidx (tuple): idx is a dictionary mapping word to row number
                        iidx is a dictionary mapping row number to word
    """
    model.wv.fill_norms()
    embeddings = deepcopy(model.wv.get_normed_vectors())
    idx = {w: i for i, w in enumerate(model.wv.index_to_key)}
    iidx = {i: w for i, w in enumerate(model.wv.index_to_key)}
    return embeddings, (idx, iidx)

# %%
en_emb, en_item = w2v_to_numpy(english_model)
de_emb, de_item = w2v_to_numpy(german_model)

# %%
print(en_item[1])
# Out:
# {0: 'european', 1: 'mr', 2: 'commission', 3: 'would', 4: 'also', 5: 'president', 6: 'member', 7: 'must', 8: 'make', 9: 'country', 10: 'union', 11: 'parliament', 12: 'take', 13: 'report', 14: 'council', 15: 'need', 16: 'states', 17: 'like', 18: 'one', 19: 'europe', 20: 'say', 21: 'right', 22: "'s", 23: 'policy', 24: 'eu', 25: 'people', 26: 'work', 27: 'time', 28: 'year', 29: 'issue', 30: 'support', 31: 'new', 32: 'proposal', 33: 'important', 34: 'give', 35: 'well', 36: 'therefore', 37: 'point', 38: 'however', 39: '\xa0', 40: 'state', 41: 'committee', 42: 'use', 43: 'vote', 44: 'way', 45: '\xa0\xa0 ', 46: 'debate', 47: 'group', 48: 'commissioner', 49: 'concern', 50: 'development', 51: 'area', 52: 'believe', 53: 'political', 54: 'market', 55: 'good', 56: 'question', 57: 'problem', 58: 'first', 59: '’s', 60: 'want', 61: 'amendment', 62: 'many', 63: 'agreement', 64: 'great', 65: 'regard', 66: 'see', 67: 'go', 68: 'fact', 69: 'social', 70: 'economic', 71: 'human', 72: 'community', 73: 'directive', 74: 'thank', 75: 'even', 76: 'know', 77: 'case', 78: 'part', 79: 'think', 80: 'measure', 81: 'situation', 82: 'public', 83: 'come', 84: 'two', 85: 'order', 86: 'today', 87: 'mean', 88: 'world', 89: 'government', 90: 'citizen', 91: 'system', 92: 'action', 93: 'view', 94: 'call', 95: 'term', 96: 'future', 97: 'programme', 98: 'national', 99: 'level', 100: 'decision', 101: 'include', 102: 'possible', 103: 'provide', 104: 'could', 105: 'clear', 106: 'much', 107: 'long', 108: 'rule', 109: 'within', 110: 'ensure', 111: 'place', 112: 'international', 113: 'matter', 114: 'hope', 115: 'already', 116: 'far', 117: 'adopt', 118: 'may', 119: 'common', 120: 'process', 121: 'increase', 122: 'rapporteur', 123: 'put', 124: 'result', 125: 'service', 126: 'still', 127: 'cooperation', 128: 'change', 129: 'present', 130: 'mrs', 131: 'ask', 132: 'last', 133: 'course', 134: 'example', 135: 'house', 136: 'particular', 137: 'agree', 138: 'law', 139: 'propose', 140: 'achieve', 141: 'regulation', 142: 'number', 143: 'able', 144: 'set', 145: 'security', 146: 'financial', 147: 'respect', 148: 'without', 149: 'continue', 150: 'principle', 151: 'end', 152: 'position', 153: 'gentleman', 154: 'lady', 155: 'energy', 156: 'region', 157: 'information', 158: 'interest', 159: 'budget', 160: 'deal', 161: 'united', 162: 'sector', 163: 'legal', 164: 'resolution', 165: 'health', 166: 'treaty', 167: 'objective', 168: 'since', 169: 'woman', 170: 'develop', 171: 'presidency', 172: 'thing', 173: 'wish', 174: 'protection', 175: 'find', 176: 'high', 177: 'trade', 178: 'reason', 179: 'allow', 180: 'fund', 181: 'follow', 182: 'bring', 183: 'reform', 184: 'help', 185: 'create', 186: 'opportunity', 187: 'become', 188: 'party', 189: 'framework', 190: 'particularly', 191: 'procedure', 192: 'whether', 193: 'institution', 194: 'authority', 195: 'necessary', 196: 'consider', 197: 'basis', 198: 'welcome', 199: 'let', 200: 'behalf', 201: 'involve', 202: 'aid', 203: 'strategy', 204: 'next', 205: 'opinion', 206: 'general', 207: 'legislation', 208: 'apply', 209: 'role', 210: 'certain', 211: 'subject', 212: 'force', 213: 'relation', 214: 'get', 215: 'effort', 216: 'look', 217: 'different', 218: 'improve', 219: 'progress', 220: 'consumer', 221: 'responsibility', 222: 'favour', 223: 'approach', 224: 'mention', 225: 'base', 226: 'initiative', 227: 'control', 228: 'lead', 229: 'industry', 230: 'plan', 231: 'something', 232: 'speak', 233: 'freedom', 234: 'research', 235: 'show', 236: 'product', 237: 'million', 238: 'implement', 239: 'accept', 240: 'establish', 241: 'three', 242: 'environment', 243: 'another', 244: 'transport', 245: 'condition', 246: 'aim', 247: 'word', 248: 'account', 249: 'forward', 250: 'day', 251: 'project', 252: 'second', 253: 'express', 254: 'whole', 255: 'safety', 256: 'reach', 257: 'step', 258: 'form', 259: 'fundamental', 260: 'talk', 261: 'large', 262: 'shall', 263: 'negotiation', 264: 'life', 265: 'every', 266: 'madam', 267: 'together', 268: 'power', 269: 'require', 270: 'remain', ...

# %%
def procrustes(A, B):
    """
    Solve the orthogonal Procrustes problem which finds the matrix R that
    best maps matrix A onto matrix B under orthogonal transformation.
    
    Parameters:
    A (numpy.ndarray): The source matrix.
    B (numpy.ndarray): The target matrix to map A onto.

    Returns:
    numpy.ndarray: The orthogonal matrix R.
    """
    # Compute the matrix product of A^T and B
    M = A.T @ B
    
    # Perform Singular Value Decomposition
    U, _, Vt = np.linalg.svd(M)
    
    # Compute R as U * V^T
    R = U @ Vt
    
    return R

# %%
train_path = os.path.join('train_test_data','train_set.txt')
test_path = os.path.join('train_test_data','test_set.txt')
with open(train_path, 'r') as f:
    train_set = f.read().splitlines()
with open(test_path, 'r') as f:
    test_set = f.read().splitlines()

# %%
len(train_set)
# Out:
# 875

# %%
def create_words_and_indices(data):
    english_words = []
    german_words = []
    english_indices = []
    german_indices = []
    
    for item in data:
        parts = item.split()
        english_words.append(parts[0])
        german_words.append(parts[1])
        english_indices.append(int(parts[2]))
        german_indices.append(int(parts[3]))
    return english_words, german_words, english_indices, german_indices

# %%
en_words, de_words, en_indices, de_indices = create_words_and_indices(train_set)

# %%
def create_anchor_matrix(matrix, indices):
    """
    Create a matrix with only the anchor words
    """
    return matrix[indices]

# %%
en_anchor = create_anchor_matrix(en_emb, en_indices)
de_anchor = create_anchor_matrix(de_emb, de_indices)

# %%
print(en_anchor.shape)
print(de_anchor.shape)
# Out:
# (875, 50)
# (875, 50)

# %%
# Since we want to map the English anchor words to the German anchor words,
p_matrix = procrustes(de_anchor, en_anchor)

# %%
de_english_aligned = de_emb @ p_matrix

# %%
# print l2 by row
print(np.linalg.norm(de_english_aligned, axis=1))
print(np.linalg.norm(de_english_aligned, axis=1).shape)
for item in np.linalg.norm(de_english_aligned, axis=1):
    if item < 0.999 or item > 1.001:
        print(item)
        print('error')
# Out:
# [1.         1.         0.99999994 ... 0.99999994 0.99999994 0.9999999 ]
# (60960,)

# %%
# find closest 
def find_closest_words(aligned_vector, target_matrix, iidx, n=5):
    dot_product = aligned_vector @ target_matrix.T
    closest_indices = np.argsort(dot_product)[::-1][:n]
    return [iidx[i] for i in closest_indices]

find_closest_words(de_english_aligned[100], en_emb, en_item[1])
# Out:
# ['security', 'safety', 'protection', 'justice', 'efficiency']

# %%
top_1_count = 0
total_count = 0
for i, j in enumerate(de_indices):
    aligned_vector = de_english_aligned[j]
    closest_word = find_closest_words(aligned_vector, en_emb, en_item[1], 1)[0]
    english_index = en_indices[i]
    gold_word = en_item[1][english_index]
    if closest_word == gold_word:
        print(f'Correctly aligned {gold_word} to {closest_word}')
        top_1_count += 1
    else:
        print(f'Incorrectly aligned {gold_word} to {closest_word}')
    total_count += 1
print(f'Top 1 accuracy: {top_1_count/total_count}')
print(f'Total count: {total_count}')
# Out:
# Incorrectly aligned 2002 to 2003
# Correctly aligned government to government
# Correctly aligned exclude to exclude
# Incorrectly aligned vehicle to lorry
# Correctly aligned project to project
# Correctly aligned difficulty to difficulty
# Correctly aligned politician to politician
# Correctly aligned racism to racism
# Incorrectly aligned west to western
# Correctly aligned unnecessary to unnecessary
# Correctly aligned 80 to 80
# Correctly aligned investigation to investigation
# Incorrectly aligned historical to historic
# Correctly aligned five to five
# Correctly aligned continent to continent
# Incorrectly aligned train to imminent
# Incorrectly aligned 27 to 25
# Correctly aligned legislation to legislation
# Correctly aligned union to union
# Correctly aligned require to require
# Correctly aligned early to early
# Correctly aligned restrict to restrict
# Correctly aligned direct to direct
# Correctly aligned participation to participation
# Correctly aligned immigration to immigration
# Correctly aligned advocate to advocate
# Correctly aligned chechnya to chechnya
# Correctly aligned method to method
# Correctly aligned regrettable to regrettable
# Correctly aligned culture to culture
# Correctly aligned 4 to 4
# Correctly aligned 2010 to 2010
# Correctly aligned infrastructure to infrastructure
# Correctly aligned protocol to protocol
# Incorrectly aligned shape to form
# Correctly aligned old to old
# Incorrectly aligned 21 to 11
# Incorrectly aligned claim to entitlement
# Correctly aligned former to former
# Correctly aligned successful to successful
# Incorrectly aligned green to greens
# Correctly aligned security to security
# Correctly aligned choose to choose
# Correctly aligned several to several
# Correctly aligned lisbon to lisbon
# Correctly aligned see to see
# Correctly aligned amendment to amendment
# Correctly aligned useful to useful
# Incorrectly aligned fish to forestry
# Incorrectly aligned available to exist
# Correctly aligned attack to attack
# Incorrectly aligned reinforce to enhanced
# Incorrectly aligned bank to company
# Incorrectly aligned win to visible
# Incorrectly aligned call to include
# Incorrectly aligned 1 to 3
# Incorrectly aligned want to wish
# Correctly aligned religious to religious
# Correctly aligned improve to improve
# Incorrectly aligned investigate to analyse
# Correctly aligned sanction to sanction
# Correctly aligned information to information
# Correctly aligned immigrant to immigrant
# Correctly aligned efficient to efficient
# Correctly aligned mr to mr
# Correctly aligned responsibility to responsibility
# Correctly aligned rural to rural
# Correctly aligned structure to structure
# Incorrectly aligned author to bg
# Correctly aligned sustainability to sustainability
# Incorrectly aligned united to foreign
# Correctly aligned phase to phase
# Correctly aligned four to four
# Correctly aligned life to life
# Correctly aligned palestinians to palestinians
# Correctly aligned africa to africa
# Correctly aligned sustainable to sustainable
# Correctly aligned strong to strong
# Correctly aligned family to family
# Correctly aligned regret to regret
# Correctly aligned loss to loss
# Correctly aligned doubt to doubt
# Incorrectly aligned requirement to precondition
# Incorrectly aligned currency to monetary
# Correctly aligned strasbourg to strasbourg
# Correctly aligned company to company
# Correctly aligned stable to stable
# Incorrectly aligned politic to policy
# Correctly aligned play to play
# Correctly aligned ratify to ratify
# Correctly aligned aspect to aspect
# Correctly aligned 14 to 14
# Incorrectly aligned 2 to 3
# Correctly aligned 2007 to 2007
# Incorrectly aligned van to cassiotou
# Correctly aligned mobility to mobility
# Correctly aligned flexible to flexible
# Incorrectly aligned suggest to propose
# Correctly aligned iraq to iraq
# Correctly aligned week to week
# Correctly aligned facilitate to facilitate
# Correctly aligned territorial to territorial
# Incorrectly aligned politically to political
# Incorrectly aligned question to tell
# Correctly aligned weak to weak
# Incorrectly aligned exercise to maintain
# Correctly aligned couple to couple
# Correctly aligned react to react
# Correctly aligned period to period
# Incorrectly aligned violate to infringe
# Incorrectly aligned course to precede
# Correctly aligned active to active
# Correctly aligned event to event
# Incorrectly aligned describe to portray
# Incorrectly aligned fully to totally
# Correctly aligned ethnic to ethnic
# Correctly aligned lebanon to lebanon
# Correctly aligned procedure to procedure
# Correctly aligned poverty to poverty
# Correctly aligned never to never
# Incorrectly aligned stand to embark
# Incorrectly aligned reaction to response
# Correctly aligned condition to condition
# Incorrectly aligned focus to concentrate
# Correctly aligned background to background
# Correctly aligned context to context
# Correctly aligned part to part
# Correctly aligned double to double
# Correctly aligned charter to charter
# Correctly aligned authority to authority
# Incorrectly aligned table to back
# Correctly aligned fundamental to fundamental
# Correctly aligned consideration to consideration
# Correctly aligned terrorism to terrorism
# Incorrectly aligned seek to search
# Correctly aligned 1998 to 1998
# Correctly aligned success to success
# Correctly aligned support to support
# Correctly aligned partnership to partnership
# Correctly aligned list to list
# Correctly aligned relationship to relationship
# Correctly aligned flexibility to flexibility
# Incorrectly aligned 60 to 50
# Correctly aligned approach to approach
# Correctly aligned serve to serve
# Correctly aligned signal to signal
# Correctly aligned crisis to crisis
# Correctly aligned institutional to institutional
# Correctly aligned example to example
# Correctly aligned protect to protect
# Correctly aligned oral to oral
# Correctly aligned seem to seem
# Incorrectly aligned internal to administrative
# Correctly aligned interest to interest
# Correctly aligned introduction to introduction
# Incorrectly aligned directly to serious
# Incorrectly aligned continue to intensify
# Correctly aligned majority to majority
# Correctly aligned receive to receive
# Incorrectly aligned limit to limited
# Incorrectly aligned order to liberty
# Correctly aligned december to december
# Correctly aligned go to go
# Correctly aligned austrian to austrian
# Incorrectly aligned group to grouping
# Incorrectly aligned occasion to prominence
# Correctly aligned although to although
# Correctly aligned delegation to delegation
# Incorrectly aligned foreign to boss
# Correctly aligned commission to commission
# Correctly aligned initiate to initiate
# Correctly aligned use to use
# Correctly aligned immediately to immediately
# Correctly aligned renewable to renewable
# Incorrectly aligned agricultural to arable
# Incorrectly aligned grant to give
# Correctly aligned sensitive to sensitive
# Correctly aligned proud to proud
# Correctly aligned determine to determine
# Correctly aligned spend to spend
# Incorrectly aligned pay to repay
# Correctly aligned day to day
# Correctly aligned capacity to capacity
# Incorrectly aligned 20 to 50
# Correctly aligned confirm to confirm
# Correctly aligned population to population
# Correctly aligned contribution to contribution
# Correctly aligned undoubtedly to undoubtedly
# Incorrectly aligned half to nearly
# Correctly aligned competition to competition
# Correctly aligned growth to growth
# Incorrectly aligned job to speaker
# Correctly aligned competence to competence
# Correctly aligned secondly to secondly
# Correctly aligned message to message
# Correctly aligned constant to constant
# Correctly aligned speak to speak
# Correctly aligned terrorist to terrorist
# Correctly aligned fact to fact
# Correctly aligned mandate to mandate
# Correctly aligned wait to wait
# Incorrectly aligned begin to start
# Incorrectly aligned morning to tomorrow
# Correctly aligned therefore to therefore
# Correctly aligned difficult to difficult
# Incorrectly aligned euro to 2.8
# Correctly aligned pl to pl
# Correctly aligned door to door
# Correctly aligned consequently to consequently
# Incorrectly aligned concept to approach
# Incorrectly aligned currently to current
# Incorrectly aligned record to admission
# Correctly aligned 2004 to 2004
# Correctly aligned belarus to belarus
# Correctly aligned denmark to denmark
# Correctly aligned israeli to israeli
# Incorrectly aligned proof to evidence
# Correctly aligned agency to agency
# Incorrectly aligned trust to confidence
# Incorrectly aligned together to common
# Incorrectly aligned drive to fly
# Correctly aligned introduce to introduce
# Correctly aligned transparency to transparency
# Incorrectly aligned drug to medicine
# Correctly aligned standard to standard
# Correctly aligned france to france
# Correctly aligned article to article
# Incorrectly aligned leave to stay
# Incorrectly aligned balance to balanced
# Incorrectly aligned probably to none
# Correctly aligned diversity to diversity
# Correctly aligned bind to bind
# Incorrectly aligned business to economy
# Correctly aligned decision to decision
# Incorrectly aligned might to power
# Correctly aligned numerous to numerous
# Incorrectly aligned ever to even
# Correctly aligned strengthen to strengthen
# Correctly aligned agriculture to agriculture
# Correctly aligned cost to cost
# Correctly aligned evaluation to evaluation
# Correctly aligned extensive to extensive
# Correctly aligned prepare to prepare
# Correctly aligned justify to justify
# Correctly aligned know to know
# Correctly aligned however to however
# Incorrectly aligned member to meps
# Correctly aligned damage to damage
# Incorrectly aligned 30 to 50
# Correctly aligned source to source
# Correctly aligned 2013 to 2013
# Correctly aligned argument to argument
# Incorrectly aligned 5 to 3
# Incorrectly aligned attempt to try
# Correctly aligned negotiate to negotiate
# Correctly aligned public to public
# Incorrectly aligned express to confirm
# Correctly aligned subsidiarity to subsidiarity
# Correctly aligned bilateral to bilateral
# Correctly aligned criticism to criticism
# Correctly aligned 1999 to 1999
# Incorrectly aligned date to datum
# Incorrectly aligned remember to remind
# Correctly aligned technological to technological
# Correctly aligned speaker to speaker
# Incorrectly aligned form to establish
# Correctly aligned 15 to 15
# Incorrectly aligned traffic to transport
# Correctly aligned invest to invest
# Correctly aligned recognition to recognition
# Incorrectly aligned like to none
# Correctly aligned kingdom to kingdom
# Correctly aligned second to second
# Incorrectly aligned run to materialise
# Correctly aligned namely to namely
# Incorrectly aligned january to june
# Incorrectly aligned wish to confident
# Correctly aligned realistic to realistic
# Correctly aligned adoption to adoption
# Correctly aligned reconstruction to reconstruction
# Correctly aligned accident to accident
# Correctly aligned protection to protection
# Incorrectly aligned appeal to urge
# Correctly aligned national to national
# Correctly aligned cyprus to cyprus
# Correctly aligned perhaps to perhaps
# Incorrectly aligned suggestion to proposal
# Correctly aligned friend to friend
# Correctly aligned million to million
# Correctly aligned tradition to tradition
# Incorrectly aligned occupy to discuss
# Correctly aligned please to please
# Incorrectly aligned america to americans
# Incorrectly aligned special to particular
# Correctly aligned open to open
# Correctly aligned sometimes to sometimes
# Correctly aligned polish to polish
# Correctly aligned worldwide to worldwide
# Incorrectly aligned clarify to reiterate
# Correctly aligned full to full
# Correctly aligned conflict to conflict
# Correctly aligned clear to clear
# Correctly aligned submit to submit
# Correctly aligned reality to reality
# Incorrectly aligned back to daddy
# Correctly aligned truth to truth
# Correctly aligned discrimination to discrimination
# Incorrectly aligned guarantee to ensure
# Correctly aligned normal to normal
# Correctly aligned paragraph to paragraph
# Correctly aligned effective to effective
# Incorrectly aligned material to cadmium
# Correctly aligned 18 to 18
# Correctly aligned seat to seat
# Correctly aligned rich to rich
# Incorrectly aligned daily to everyday
# Correctly aligned internet to internet
# Correctly aligned soon to soon
# Incorrectly aligned affect to affected
# Correctly aligned colleague to colleague
# Incorrectly aligned place to deal
# Correctly aligned strategy to strategy
# Incorrectly aligned power to force
# Correctly aligned fr to fr
# Incorrectly aligned track to pursue
# Incorrectly aligned regime to dictator
# Correctly aligned die to die
# Incorrectly aligned yes to none
# Correctly aligned consumer to consumer
# Correctly aligned specific to specific
# Correctly aligned difference to difference
# Correctly aligned option to option
# Correctly aligned romania to romania
# Correctly aligned risk to risk
# Incorrectly aligned discussion to debate
# Incorrectly aligned arise to create
# Incorrectly aligned concrete to practical
# Correctly aligned threaten to threaten
# Incorrectly aligned opposite to perceive
# Incorrectly aligned waste to incineration
# Correctly aligned portugal to portugal
# Correctly aligned austria to austria
# Correctly aligned intention to intention
# Incorrectly aligned maintain to retain
# Correctly aligned 7 to 7
# Incorrectly aligned february to april
# Correctly aligned action to action
# Correctly aligned three to three
# Correctly aligned poor to poor
# Correctly aligned product to product
# Correctly aligned afternoon to afternoon
# Incorrectly aligned operation to factory
# Correctly aligned reform to reform
# Correctly aligned solidarity to solidarity
# Correctly aligned border to border
# Correctly aligned crime to crime
# Incorrectly aligned make to carry
# Correctly aligned alliance to alliance
# Correctly aligned bring to bring
# Incorrectly aligned urgent to urgently
# Correctly aligned mention to mention
# Correctly aligned agreement to agreement
# Correctly aligned definition to definition
# Correctly aligned money to money
# Incorrectly aligned july to april
# Correctly aligned innovative to innovative
# Correctly aligned system to system
# Correctly aligned pt to pt
# Incorrectly aligned intervention to intervene
# Correctly aligned destroy to destroy
# Correctly aligned particularly to particularly
# Correctly aligned italian to italian
# Correctly aligned largely to largely
# Correctly aligned enjoy to enjoy
# Correctly aligned show to show
# Correctly aligned presidency to presidency
# Correctly aligned remain to remain
# Incorrectly aligned convention to protocol
# Incorrectly aligned take to give
# Correctly aligned ireland to ireland
# Incorrectly aligned treat to discuss
# Incorrectly aligned floor to poison
# Incorrectly aligned result to outcome
# Incorrectly aligned scope to extent
# Correctly aligned ban to ban
# Correctly aligned french to french
# Correctly aligned evaluate to evaluate
# Incorrectly aligned construction to creation
# Correctly aligned 2008 to 2008
# Incorrectly aligned help to assistance
# Correctly aligned communist to communist
# Incorrectly aligned advantage to benefit
# Correctly aligned impression to impression
# Correctly aligned defend to defend
# Correctly aligned dangerous to dangerous
# Correctly aligned analysis to analysis
# Correctly aligned unfortunately to unfortunately
# Incorrectly aligned human to genotype
# Incorrectly aligned afford to contribute
# Correctly aligned model to model
# Incorrectly aligned legal to migrant
# Correctly aligned overcome to overcome
# Incorrectly aligned judge to call
# Correctly aligned process to process
# Correctly aligned access to access
# Correctly aligned sweden to sweden
# Incorrectly aligned policy to directive
# Correctly aligned chinese to chinese
# Correctly aligned 100 to 100
# Correctly aligned remark to remark
# Correctly aligned industry to industry
# Correctly aligned expectation to expectation
# Correctly aligned independent to independent
# Incorrectly aligned lay to lie
# Correctly aligned regulation to regulation
# Correctly aligned billion to billion
# Correctly aligned draft to draft
# Incorrectly aligned represent to constitute
# Correctly aligned interesting to interesting
# Correctly aligned per to per
# Correctly aligned complex to complex
# Correctly aligned military to military
# Correctly aligned broad to broad
# Correctly aligned guideline to guideline
# Correctly aligned assembly to assembly
# Incorrectly aligned aid to subsidy
# Incorrectly aligned sea to polluted
# Incorrectly aligned closely to close
# Correctly aligned practice to practice
# Correctly aligned grow to grow
# Incorrectly aligned expression to endorsement
# Correctly aligned negative to negative
# Correctly aligned value to value
# Correctly aligned status to status
# Correctly aligned impact to impact
# Correctly aligned equality to equality
# Correctly aligned republic to republic
# Correctly aligned 3 to 3
# Correctly aligned mechanism to mechanism
# Correctly aligned local to local
# Incorrectly aligned intensive to fruitful
# Incorrectly aligned large to enormous
# Incorrectly aligned accordingly to appropriate
# Correctly aligned summit to summit
# Correctly aligned march to march
# Correctly aligned parliamentary to parliamentary
# Incorrectly aligned away to i.e.
# Correctly aligned today to today
# Correctly aligned europe to europe
# Correctly aligned expect to expect
# Correctly aligned india to india
# Incorrectly aligned complete to obligatory
# Correctly aligned practical to practical
# Correctly aligned base to base
# Correctly aligned two to two
# Incorrectly aligned detail to detailed
# Incorrectly aligned finish to restart
# Correctly aligned research to research
# Incorrectly aligned demand to call
# Incorrectly aligned consider to believe
# Correctly aligned democracy to democracy
# Correctly aligned network to network
# Correctly aligned discharge to discharge
# Correctly aligned conference to conference
# Correctly aligned victim to victim
# Correctly aligned october to october
# Correctly aligned 16 to 16
# Correctly aligned deadline to deadline
# Correctly aligned etc to etc
# Incorrectly aligned liberal to socialist
# Correctly aligned initiative to initiative
# Correctly aligned sovereignty to sovereignty
# Correctly aligned moment to moment
# Correctly aligned official to official
# Incorrectly aligned suspend to expose
# Correctly aligned 25 to 25
# Correctly aligned sign to sign
# Correctly aligned credibility to credibility
# Correctly aligned effect to effect
# Correctly aligned succeed to succeed
# Correctly aligned palestine to palestine
# Correctly aligned serbia to serbia
# Incorrectly aligned short to brief
# Correctly aligned withdraw to withdraw
# Incorrectly aligned request to urge
# Correctly aligned nation to nation
# Incorrectly aligned correct to worthwhile
# Correctly aligned 000 to 000
# Correctly aligned finally to finally
# Correctly aligned already to already
# Correctly aligned thus to thus
# Correctly aligned constitution to constitution
# Correctly aligned prevention to prevention
# Incorrectly aligned start to begin
# Correctly aligned institution to institution
# Incorrectly aligned integrate to integrated
# Correctly aligned small to small
# Correctly aligned animal to animal
# Correctly aligned decade to decade
# Correctly aligned speech to speech
# Correctly aligned restriction to restriction
# Correctly aligned tourism to tourism
# Correctly aligned debate to debate
# Correctly aligned heart to heart
# Correctly aligned obstacle to obstacle
# Correctly aligned gender to gender
# Correctly aligned consequence to consequence
# Incorrectly aligned employ to specialise
# Correctly aligned develop to develop
# Correctly aligned recommend to recommend
# Correctly aligned priority to priority
# Correctly aligned future to future
# Incorrectly aligned possibly to actually
# Correctly aligned create to create
# Correctly aligned need to need
# Incorrectly aligned opportunity to occasion
# Incorrectly aligned observe to witness
# Correctly aligned european to european
# Correctly aligned referendum to referendum
# Correctly aligned 2006 to 2006
# Correctly aligned east to east
# Correctly aligned prove to prove
# Correctly aligned mistake to mistake
# Correctly aligned approve to approve
# Correctly aligned ii to ii
# Correctly aligned russian to russian
# Correctly aligned global to global
# Correctly aligned document to document
# Correctly aligned delay to delay
# Correctly aligned nato to nato
# Correctly aligned nl to nl
# Correctly aligned journalist to journalist
# Correctly aligned interinstitutional to interinstitutional
# Incorrectly aligned employee to worker
# Correctly aligned thursday to thursday
# Correctly aligned production to production
# Correctly aligned also to also
# Correctly aligned staff to staff
# Incorrectly aligned check to examine
# Correctly aligned pressure to pressure
# Correctly aligned plan to plan
# Incorrectly aligned get to communicate
# Incorrectly aligned choice to election
# Incorrectly aligned eye to europe
# Correctly aligned significant to significant
# Correctly aligned effort to effort
# Incorrectly aligned secure to safe
# Incorrectly aligned exchange to networking
# Incorrectly aligned transport to transportation
# Correctly aligned century to century
# Correctly aligned deficit to deficit
# Correctly aligned application to application
# Correctly aligned offer to offer
# Incorrectly aligned danish to austrian
# Correctly aligned citizen to citizen
# Correctly aligned combat to combat
# Correctly aligned contact to contact
# Incorrectly aligned decisive to crucial
# Correctly aligned approval to approval
# Incorrectly aligned reasonable to sensible
# Correctly aligned competitiveness to competitiveness
# Correctly aligned 2001 to 2001
# Incorrectly aligned exception to derogation
# Incorrectly aligned underline to stress
# Correctly aligned whole to whole
# Incorrectly aligned even to equal
# Correctly aligned let to let
# Correctly aligned potential to potential
# Incorrectly aligned nature to landscape
# Correctly aligned monitor to monitor
# Incorrectly aligned effectively to effective
# Incorrectly aligned true to noble
# Incorrectly aligned june to december
# Incorrectly aligned present to draft
# Incorrectly aligned primarily to mainly
# Incorrectly aligned past to last
# Incorrectly aligned absolutely to therefore
# Incorrectly aligned light to easy
# Correctly aligned progress to progress
# Correctly aligned c5 to c5
# Incorrectly aligned follow to following
# Correctly aligned exploitation to exploitation
# Correctly aligned forum to forum
# Incorrectly aligned hold to seem
# Incorrectly aligned glad to happy
# Correctly aligned problem to problem
# Incorrectly aligned increasingly to grow
# Correctly aligned increase to increase
# Correctly aligned fund to fund
# Correctly aligned war to war
# Incorrectly aligned medium to funding
# Correctly aligned american to american
# Correctly aligned ukraine to ukraine
# Correctly aligned russia to russia
# Correctly aligned valuable to valuable
# Correctly aligned possible to possible
# Correctly aligned budget to budget
# Correctly aligned transatlantic to transatlantic
# Correctly aligned child to child
# Correctly aligned enough to enough
# Correctly aligned energy to energy
# Incorrectly aligned quickly to rapidly
# Correctly aligned thorough to thorough
# Correctly aligned greece to greece
# Correctly aligned coordination to coordination
# Incorrectly aligned learn to teach
# Correctly aligned consensus to consensus
# Incorrectly aligned 2000 to 2003
# Incorrectly aligned address to mention
# Correctly aligned iran to iran
# Correctly aligned technology to technology
# Correctly aligned solution to solution
# Correctly aligned spirit to spirit
# Correctly aligned publish to publish
# Incorrectly aligned cause to symptom
# Correctly aligned picture to picture
# Correctly aligned dependent to dependent
# Correctly aligned case to case
# Incorrectly aligned cheap to favourable
# Incorrectly aligned eight to four
# Correctly aligned multilateral to multilateral
# Incorrectly aligned test to examination
# Correctly aligned excellent to excellent
# Correctly aligned justice to justice
# Correctly aligned peaceful to peaceful
# Incorrectly aligned regard to relate
# Incorrectly aligned barcelona to stockholm
# Correctly aligned contain to contain
# Correctly aligned court to court
# Correctly aligned word to word
# Correctly aligned month to month
# Incorrectly aligned environment to environmental
# Correctly aligned identity to identity
# Incorrectly aligned tax to taxis
# Correctly aligned tragic to tragic
# Incorrectly aligned concern to relevant
# Correctly aligned really to really
# Incorrectly aligned always to still
# Correctly aligned zimbabwe to zimbabwe
# Correctly aligned component to component
# Correctly aligned fisherman to fisherman
# Correctly aligned market to market
# Correctly aligned instrument to instrument
# Correctly aligned thing to thing
# Correctly aligned health to health
# Correctly aligned positive to positive
# Incorrectly aligned climate to atmosphere
# Correctly aligned convince to convince
# Correctly aligned rapporteur to rapporteur
# Incorrectly aligned intend to envisage
# Correctly aligned number to number
# Correctly aligned reason to reason
# Incorrectly aligned retain to comply
# Correctly aligned humanitarian to humanitarian
# Incorrectly aligned refuse to reject
# Correctly aligned factor to factor
# Incorrectly aligned feel to europeans
# Correctly aligned danger to danger
# Correctly aligned matter to matter
# Correctly aligned portuguese to portuguese
# Incorrectly aligned ask to issue
# Incorrectly aligned guide to leadership
# Correctly aligned airport to airport
# Incorrectly aligned extent to cause
# Correctly aligned promise to promise
# Incorrectly aligned produce to harness
# Incorrectly aligned far to precisely
# Correctly aligned service to service
# Correctly aligned category to category
# Incorrectly aligned generally to general
# Correctly aligned recently to recently
# Correctly aligned clearly to clearly
# Correctly aligned new to new
# Incorrectly aligned permit to authorisation
# Incorrectly aligned miss to lack
# Incorrectly aligned 11 to post-11
# Incorrectly aligned come to bring
# Incorrectly aligned involve to stakeholder
# Correctly aligned criterion to criterion
# Incorrectly aligned belong to include
# Correctly aligned healthy to healthy
# Correctly aligned resolution to resolution
# Incorrectly aligned satisfied to satisfactory
# Correctly aligned enforcement to enforcement
# Incorrectly aligned believe to think
# Correctly aligned language to language
# Correctly aligned package to package
# Correctly aligned must to must
# Correctly aligned apply to apply
# Incorrectly aligned achievement to attain
# Correctly aligned visit to visit
# Correctly aligned african to african
# Correctly aligned independence to independence
# Correctly aligned outside to outside
# Correctly aligned accordance to accordance
# Correctly aligned bad to bad
# Incorrectly aligned central to key
# Correctly aligned ratification to ratification
# Correctly aligned refer to refer
# Correctly aligned china to china
# Correctly aligned repeat to repeat
# Correctly aligned necessary to necessary
# Correctly aligned unacceptable to unacceptable
# Incorrectly aligned battle to fight
# Correctly aligned yesterday to yesterday
# Incorrectly aligned sensible to useful
# Correctly aligned define to define
# Incorrectly aligned conviction to belief
# Incorrectly aligned certainly to certain
# Incorrectly aligned emission to co2
# Correctly aligned statistic to statistic
# Incorrectly aligned death to rapist
# Correctly aligned president to president
# Correctly aligned 6 to 6
# Incorrectly aligned fall to assign
# Incorrectly aligned enter to raise
# Correctly aligned answer to answer
# Correctly aligned low to low
# Incorrectly aligned relation to regard
# Correctly aligned complaint to complaint
# Correctly aligned afghanistan to afghanistan
# Incorrectly aligned notice to indicate
# Correctly aligned stability to stability
# Correctly aligned commissioner to commissioner
# Correctly aligned peace to peace
# Correctly aligned find to find
# Correctly aligned report to report
# Correctly aligned hand to hand
# Correctly aligned development to development
# Incorrectly aligned amount to sum
# Correctly aligned point to point
# Incorrectly aligned six to five
# Incorrectly aligned relate to pertain
# Correctly aligned responsible to responsible
# Correctly aligned task to task
# Correctly aligned free to free
# Incorrectly aligned constantly to preparation
# Correctly aligned attention to attention
# Correctly aligned write to write
# Incorrectly aligned deep to profound
# Correctly aligned negotiation to negotiation
# Correctly aligned extremely to extremely
# Correctly aligned text to text
# Correctly aligned challenge to challenge
# Correctly aligned first to first
# Correctly aligned avoid to avoid
# Correctly aligned discuss to discuss
# Correctly aligned generation to generation
# Incorrectly aligned serious to seriousness
# Correctly aligned april to april
# Correctly aligned situation to situation
# Correctly aligned threat to threat
# Correctly aligned fear to fear
# Correctly aligned version to version
# Correctly aligned ship to ship
# Correctly aligned good to good
# Correctly aligned reach to reach
# Correctly aligned extreme to extreme
# Incorrectly aligned close to conclude
# Correctly aligned unanimously to unanimously
# Correctly aligned hour to hour
# Correctly aligned implement to implement
# Correctly aligned external to external
# Correctly aligned belgium to belgium
# Correctly aligned freedom to freedom
# Correctly aligned german to german
# Incorrectly aligned 13 to 16
# Correctly aligned croatia to croatia
# Correctly aligned prosperity to prosperity
# Correctly aligned compromise to compromise
# Incorrectly aligned lady to
# Incorrectly aligned essential to essentially
# Incorrectly aligned advice to council
# Correctly aligned actually to actually
# Correctly aligned basis to basis
# Incorrectly aligned carry to depend
# Correctly aligned element to element
# Correctly aligned objective to objective
# Correctly aligned italy to italy
# Correctly aligned someone to someone
# Incorrectly aligned de to kahn
# Incorrectly aligned late to later
# Incorrectly aligned appropriate to adequate
# Correctly aligned sufficient to sufficient
# Correctly aligned corruption to corruption
# Correctly aligned traditional to traditional
# Correctly aligned next to next
# Correctly aligned greek to greek
# Correctly aligned explain to explain
# Correctly aligned el to el
# Incorrectly aligned consist to constitute
# Correctly aligned farmer to farmer
# Correctly aligned payment to payment
# Incorrectly aligned build to construct
# Incorrectly aligned allow to permit
# Incorrectly aligned agree to endorse
# Incorrectly aligned people to nation
# Correctly aligned transparent to transparent
# Correctly aligned reduction to reduction
# Correctly aligned private to private
# Incorrectly aligned mission to enrichment
# Correctly aligned education to education
# Correctly aligned implementation to implementation
# Correctly aligned inform to inform
# Correctly aligned control to control
# Correctly aligned alone to alone
# Correctly aligned world to world
# Correctly aligned improvement to improvement
# Correctly aligned november to november
# Correctly aligned eu to eu
# Correctly aligned europol to europol
# Incorrectly aligned feature to provide
# Correctly aligned despite to despite
# Correctly aligned decide to decide
# Incorrectly aligned provision to provide
# Incorrectly aligned state to direct
# Correctly aligned resource to resource
# Incorrectly aligned interested to involve
# Correctly aligned patten to patten
# Incorrectly aligned different to various
# Incorrectly aligned goal to objective
# Correctly aligned achieve to achieve
# Incorrectly aligned join to accede
# Incorrectly aligned urge to push
# Correctly aligned duty to duty
# Correctly aligned police to police
# Correctly aligned encourage to encourage
# Correctly aligned either to either
# Correctly aligned statute to statute
# Correctly aligned community to community
# Correctly aligned firmly to firmly
# Correctly aligned end to end
# Correctly aligned accept to accept
# Correctly aligned membership to membership
# Correctly aligned profit to profit
# Correctly aligned barroso to barroso
# Correctly aligned lack to lack
# Correctly aligned minority to minority
# Correctly aligned forget to forget
# Correctly aligned fair to fair
# Correctly aligned say to say
# Correctly aligned quality to quality
# Incorrectly aligned opinion to believe
# Correctly aligned spanish to spanish
# Correctly aligned give to give
# Incorrectly aligned design to transparent
# Correctly aligned partner to partner
# Incorrectly aligned considerably to considerable
# Correctly aligned happen to happen
# Correctly aligned cuba to cuba
# Correctly aligned refugee to refugee
# Incorrectly aligned advance to consolidate
# Correctly aligned instead to instead
# Incorrectly aligned ready to prepared
# Correctly aligned cohesion to cohesion
# Incorrectly aligned distribution to dissemination
# Correctly aligned ten to ten
# Incorrectly aligned include to really
# Incorrectly aligned view to balance
# Correctly aligned poland to poland
# Correctly aligned position to position
# Incorrectly aligned meet to arrange
# Correctly aligned regional to regional
# Incorrectly aligned proceed to act
# Correctly aligned irish to irish
# Incorrectly aligned fight to eradicate
# Correctly aligned current to current
# Correctly aligned chance to chance
# Correctly aligned creation to creation
# Incorrectly aligned movement to nationalism
# Correctly aligned commit to commit
# Incorrectly aligned legally to legal
# Correctly aligned measure to measure
# Correctly aligned cooperation to cooperation
# Incorrectly aligned woman to mainstreame
# Top 1 accuracy: 0.6937142857142857
# Total count: 875

# %%
top_5_count = 0
total_count = 0
for i, j in enumerate(de_indices):
    alinged_vector = de_english_aligned[j]
    closest_words = find_closest_words(alinged_vector, en_emb, en_item[1], 5)
    english_index = en_indices[i]
    gold_word = en_item[1][english_index]
    if gold_word in closest_words:
        print(f'Correctly aligned {gold_word} to {closest_words}')
        top_5_count += 1
    else:
        print(f'Incorrectly aligned {gold_word} to {closest_words}')
    total_count += 1
print(f'Top 5 accuracy: {top_5_count/total_count}')
# Out:
# Correctly aligned 2002 to ['2003', '2002', '2001', '2005', '2006']
# Correctly aligned government to ['government', 'authority', 'cypriots', 'counterpart', 'army']
# Correctly aligned exclude to ['exclude', 'restrict', 'prohibit', 'remove', 'preclude']
# Incorrectly aligned vehicle to ['lorry', 'motorcycle', 'tyre', 'appliance', 'truck']
# Correctly aligned project to ['project', 'programme', 'fund', 'initiative', 'eit']
# Correctly aligned difficulty to ['difficulty', 'problem', 'obstacle', 'difference', 'shortcoming']
# Correctly aligned politician to ['politician', 'politic', 'elite', 'leader', 'businessman']
# Correctly aligned racism to ['racism', 'xenophobia', 'homophobia', 'radicalisation', 'racist']
# Incorrectly aligned west to ['western', 'balkan', 'maghreb', 'africa', 'neighbouring']
# Correctly aligned unnecessary to ['unnecessary', 'unnecessarily', 'excessive', 'bureaucratic', 'pointless']
# Correctly aligned 80 to ['80', '40', '70', '50', '60']
# Correctly aligned investigation to ['investigation', 'enquiry', 'examination', 'audits', 'inquiry']
# Correctly aligned historical to ['historic', 'historical', 'unique', 'momentous', 'history']
# Correctly aligned five to ['five', 'six', 'four', 'eight', 'seven']
# Correctly aligned continent to ['continent', 'europe', 'world', 'nation', 'neighbour']
# Incorrectly aligned train to ['imminent', 'eastward', 'undergo', 'light', 'speed']
# Correctly aligned 27 to ['25', '27', '15', 'fifteen', '10']
# Correctly aligned legislation to ['legislation', 'regulation', 'directive', 'law', 'provision']
# Correctly aligned union to ['union', 'eu', 'europe', 'community', 'continent']
# Correctly aligned require to ['require', 'presuppose', 'necessitate', 'need', 'provide']
# Correctly aligned early to ['early', 'late', 'happen', 'later', 'similar']
# Correctly aligned restrict to ['restrict', 'include', 'confine', 'extend', 'exclude']
# Correctly aligned direct to ['direct', 'directly', 'private', 'indirectly', 'oligarch']
# Correctly aligned participation to ['participation', 'involvement', 'representation', 'input', 'consultation']
# Correctly aligned immigration to ['immigration', 'migration', 'tackle', 'terrorism', 'asylum']
# Correctly aligned advocate to ['advocate', 'recommend', 'favour', 'oppose', 'endorse']
# Correctly aligned chechnya to ['chechnya', 'darfur', 'tibet', 'eritrea', 'iraq']
# Correctly aligned method to ['method', 'technique', 'terminology', 'methodology', 'benchmarking']
# Correctly aligned regrettable to ['regrettable', 'unfortunate', 'unusual', 'unhappy', 'unlikely']
# Correctly aligned culture to ['culture', 'cultural', 'individuality', 'civilisation', 'artistic']
# Correctly aligned 4 to ['4', '3', '2', '5', '7']
# Correctly aligned 2010 to ['2010', '2020', 'onwards', '2012', '2015']
# Correctly aligned infrastructure to ['infrastructure', 'investment', 'maintenance', 'facility', 'logistic']
# Correctly aligned protocol to ['protocol', 'biosafety', 'basilea', 'annex', 'cartagena']
# Incorrectly aligned shape to ['form', 'pretext', 'instrument', 'format', 'type']
# Correctly aligned old to ['old', 'age', 'unemployed', 'retire', 'young']
# Incorrectly aligned 21 to ['11', '17', '23', 'rio', 'post-11']
# Incorrectly aligned claim to ['entitlement', 'etcetera', 'grant', 'duty', 'disincentive']
# Correctly aligned former to ['former', 'peru', 'formerly', 'croatian', 'alberto']
# Correctly aligned successful to ['successful', 'successfully', 'success', 'good', 'smooth']
# Incorrectly aligned green to ['greens', 'abstain', 'ukip', 'overwhelmingly', 'csu']
# Correctly aligned security to ['security', 'safety', 'protection', 'justice', 'efficiency']
# Correctly aligned choose to ['choose', 'elect', 'decide', 'opt', 'belong']
# Correctly aligned several to ['several', 'numerous', 'many', 'various', 'number']
# Correctly aligned lisbon to ['lisbon', 'gothenburg', 'stockholm', 'barcelona', 'laeken']
# Correctly aligned see to ['see', 'appear', 'present', 'find', 'discuss']
# Correctly aligned amendment to ['amendment', 'amendments', 'paragraph', 'report', 'recital']
# Correctly aligned useful to ['useful', 'worthwhile', 'helpful', 'valuable', 'interesting']
# Incorrectly aligned fish to ['forestry', 'agriculture', 'fishery', 'aquaculture', 'agri']
# Incorrectly aligned available to ['exist', 'use', 'utilise', 'disposal', 'redistribute']
# Correctly aligned attack to ['attack', 'intrusion', 'hostage', 'repression', 'suppression']
# Incorrectly aligned reinforce to ['enhanced', 'intensify', 'improved', 'reinforcement', 'strengthen']
# Incorrectly aligned bank to ['company', 'corporation', 'intermediary', 'multinational', 'airbus']
# Incorrectly aligned win to ['visible', 'nurture', 'diminish', 'regain', 'instil']
# Incorrectly aligned call to ['include', 'horizontal', 'aforementioned', 'set', 'specific']
# Incorrectly aligned 1 to ['3', '4', '2', '5', '7']
# Incorrectly aligned want to ['wish', 'like', 'pleased', 'delighted', 'glad']
# Correctly aligned religious to ['religious', 'religion', 'ethnic', 'ethnicity', 'affiliation']
# Correctly aligned improve to ['improve', 'enhance', 'improved', 'improvement', 'rationalise']
# Correctly aligned investigate to ['analyse', 'examine', 'evaluate', 'assess', 'investigate']
# Correctly aligned sanction to ['sanction', 'moratorium', 'imposition', 'extradition', 'deterrent']
# Correctly aligned information to ['information', 'documentation', 'database', 'datum', 'website']
# Correctly aligned immigrant to ['immigrant', 'migrant', 'refugee', 'displace', 'repatriate']
# Correctly aligned efficient to ['efficient', 'effective', 'transparent', 'logistic', 'efficiently']
# Correctly aligned mr to ['mr', 'mr.', 'madam', 'klestil', 'bg']
# Correctly aligned responsibility to ['responsibility', 'duty', 'ability', 'interest', 'obligation']
# Correctly aligned rural to ['rural', 'multifunctionality', 'urban', 'forestry', 'multifunctional']
# Correctly aligned structure to ['structure', 'architecture', 'organisational', 'system', 'instrument']
# Incorrectly aligned author to ['bg', 'musotto', 'herrero', 'rothley', 'draftsman']
# Correctly aligned sustainability to ['sustainability', 'competitiveness', 'ecological', 'viability', 'environmental']
# Correctly aligned united to ['foreign', 'russian', 'prime', 'us', 'united']
# Correctly aligned phase to ['phase', 'stage', 'round', 'chapter', 'element']
# Correctly aligned four to ['four', 'five', 'three', 'six', 'two']
# Correctly aligned life to ['life', 'live', 'man', 'comfort', 'physically']
# Correctly aligned palestinians to ['palestinians', 'israelis', 'iraqis', 'israel', 'arabs']
# Correctly aligned africa to ['africa', 'asia', 'caucasus', 'balkans', 'south']
# Correctly aligned sustainable to ['sustainable', 'sustainability', 'harmonious', 'diversification', 'multifunctional']
# Correctly aligned strong to ['strong', 'weak', 'dynamic', 'grow', 'active']
# Correctly aligned family to ['family', 'spouse', 'elderly', 'carer', 'parent']
# Correctly aligned regret to ['regret', 'deplore', 'disappointed', 'delight', 'disappoint']
# Correctly aligned loss to ['loss', 'damage', 'harm', 'inconvenience', 'hardship']
# Correctly aligned doubt to ['doubt', 'aware', 'obviously', 'clarity', 'contradiction']
# Incorrectly aligned requirement to ['precondition', 'prerequisite', 'condition', 'guarantee', 'tool']
# Correctly aligned currency to ['monetary', 'currency', 'internal', 'homogeneous', 'markedly']
# Correctly aligned strasbourg to ['strasbourg', 'brussels', 'friday', 'sit', 'london']
# Correctly aligned company to ['company', 'business', 'multinational', 'relocate', 'entrepreneur']
# Correctly aligned stable to ['stable', 'viable', 'prosperity', 'prosperous', 'stability']
# Incorrectly aligned politic to ['policy', 'vision', 'strategy', 'cohesive', 'approach']
# Correctly aligned play to ['play', 'pivotal', 'become', 'engage', 'subordinate']
# Correctly aligned ratify to ['ratify', 'sign', 'ratification', 'signatory', 'transpose']
# Correctly aligned aspect to ['aspect', 'element', 'issue', 'point', 'factor']
# Correctly aligned 14 to ['14', '16', '18', '15', '10']
# Correctly aligned 2 to ['3', '2', '4', '5', '6']
# Correctly aligned 2007 to ['2007', '2008', '2006', '2004', '2003']
# Incorrectly aligned van to ['cassiotou', 'ouzký', 'panayotopoulos', 'hasse', 'jørgensen']
# Correctly aligned mobility to ['mobility', 'employability', 'disability', 'childcare', 'healthcare']
# Correctly aligned flexible to ['flexible', 'suitable', 'optimum', 'necessary', 'uniform']
# Correctly aligned suggest to ['propose', 'recommend', 'envisage', 'suggest', 'submit']
# Correctly aligned iraq to ['iraq', 'lebanon', 'afghanistan', 'kosovo', 'darfur']
# Correctly aligned week to ['week', 'month', 'weekend', 'day', 'monday']
# Correctly aligned facilitate to ['facilitate', 'enable', 'improve', 'hinder', 'ensure']
# Correctly aligned territorial to ['territorial', 'cohesion', 'preservation', 'regional', 'strengthening']
# Incorrectly aligned politically to ['political', 'institutional', 'democratic', 'legitimacy', 'diplomatic']
# Incorrectly aligned question to ['tell', 'wonder', 'ask', 'say', 'explain']
# Correctly aligned weak to ['weak', 'poor', 'tend', 'unfavourable', 'moderate']
# Incorrectly aligned exercise to ['maintain', 'exert', 'relinquish', 'interfere', 'obstruct']
# Correctly aligned couple to ['couple', 'four', 'nine', 'five', 'following']
# Correctly aligned react to ['react', 'respond', 'cope', 'confront', 'response']
# Correctly aligned period to ['period', '2008', 'programming', '2013', 'year']
# Correctly aligned violate to ['infringe', 'violate', 'contravene', 'flout', 'breach']
# Incorrectly aligned course to ['precede', 'lengthy', 'beginning', 'culmination', 'intense']
# Correctly aligned active to ['active', 'actively', 'encourage', 'cooperative', 'structured']
# Correctly aligned event to ['event', 'incident', 'episode', 'tragedy', 'drama']
# Correctly aligned describe to ['portray', 'describe', 'conceive', 'spell', 'invent']
# Incorrectly aligned fully to ['totally', 'completely', 'wholly', 'entirely', 'perfectly']
# Correctly aligned ethnic to ['ethnic', 'religious', 'cleansing', 'ethnicity', 'albanian']
# Correctly aligned lebanon to ['lebanon', 'palestine', 'iraq', 'syria', 'sudan']
# Correctly aligned procedure to ['procedure', 'formality', 'comitology', 'scrutiny', 'authorisation']
# Correctly aligned poverty to ['poverty', 'underdevelopment', 'marginalisation', 'illiteracy', 'inequality']
# Correctly aligned never to ['never', 'none', 'nothing', 'nobody', 'truth']
# Incorrectly aligned stand to ['embark', 'lie', 'deal', 'push', 'emerge']
# Correctly aligned reaction to ['response', 'reaction', 'react', 'stance', 'respond']
# Correctly aligned condition to ['condition', 'requirement', 'arrangement', 'circumstance', 'criterion']
# Correctly aligned focus to ['concentrate', 'focus', 'prioritise', 'include', 'consider']
# Correctly aligned background to ['background', 'backdrop', 'context', 'light', 'implication']
# Correctly aligned context to ['context', 'dimension', 'aspect', 'implication', 'architecture']
# Correctly aligned part to ['part', 'component', 'section', 'concern', 'feature']
# Correctly aligned double to ['double', 'identical', 'minimal', 'lower', 'excessive']
# Correctly aligned charter to ['charter', 'treaties', 'treaty', 'convention', 'constitution']
# Correctly aligned authority to ['authority', 'government', 'police', 'authorities', 'officer']
# Incorrectly aligned table to ['back', 'fruition', 'together', 'soon', 'nowhere']
# Correctly aligned fundamental to ['fundamental', 'key', 'crucial', 'basic', 'core']
# Correctly aligned consideration to ['consideration', 'specific', 'adaptation', 'regard', 'addition']
# Correctly aligned terrorism to ['terrorism', 'crime', 'terror', 'extremism', 'terrorist']
# Correctly aligned seek to ['search', 'find', 'seek', 'offer', 'build']
# Correctly aligned 1998 to ['1998', '1997', '2001', '1999', '2003']
# Correctly aligned success to ['success', 'achievement', 'breakthrough', 'successful', 'progress']
# Correctly aligned support to ['support', 'favour', 'endorse', 'encourage', 'assist']
# Correctly aligned partnership to ['partnership', 'dialogue', 'relationship', 'cooperation', 'enp']
# Correctly aligned list to ['list', 'ban', 'blacklist', 'register', 'inventory']
# Correctly aligned relationship to ['relationship', 'relation', 'dialogue', 'cooperation', 'engagement']
# Correctly aligned flexibility to ['flexibility', 'clarity', 'harmonisation', 'continuity', 'transparency']
# Correctly aligned 60 to ['50', '60', '40', '30', '80']
# Correctly aligned approach to ['approach', 'guideline', 'position', 'strategy', 'policy']
# Correctly aligned serve to ['serve', 'undermine', 'convert', 'promote', 'jeopardise']
# Correctly aligned signal to ['signal', 'message', 'endorsement', 'gesture', 'indication']
# Correctly aligned crisis to ['crisis', 'impasse', 'disaster', 'situation', 'tension']
# Correctly aligned institutional to ['institutional', 'organisational', 'political', 'constitutional', 'legal']
# Correctly aligned example to ['example', 'illustration', 'connection', 'experience', 'name']
# Correctly aligned protect to ['protect', 'endanger', 'safeguard', 'protection', 'detriment']
# Correctly aligned oral to ['oral', 'orally', 'tabling', 'gladly', 'floor']
# Correctly aligned seem to ['seem', 'appear', 'think', 'probably', 'somewhat']
# Incorrectly aligned internal to ['administrative', 'judicial', 'budgetary', 'supervisory', 'staffing']
# Correctly aligned interest to ['interest', 'responsibility', 'concern', 'credibility', 'ownership']
# Correctly aligned introduction to ['introduction', 'introduce', 'harmonised', 'harmonisation', 'adoption']
# Correctly aligned directly to ['serious', 'directly', 'real', 'negatively', 'major']
# Correctly aligned continue to ['intensify', 'initiate', 'relaunch', 'continue', 'undertake']
# Correctly aligned majority to ['majority', 'approval', 'vote', 'assent', 'consensus']
# Correctly aligned receive to ['receive', 'provide', 'obtain', 'give', 'offer']
# Correctly aligned limit to ['limited', 'exceed', 'limit', 'reduce', 'restrict']
# Incorrectly aligned order to ['liberty', 'independence', 'rein', 'justice', 'security']
# Correctly aligned december to ['december', 'november', 'october', 'april', 'july']
# Correctly aligned go to ['go', 'look', 'move', 'come', 'bring']
# Correctly aligned austrian to ['austrian', 'belgian', 'finnish', 'spanish', 'portuguese']
# Incorrectly aligned group to ['grouping', 'ngos', 'ngo', 'profession', 'ethnic']
# Incorrectly aligned occasion to ['prominence', 'insight', 'disappointment', 'today', 'seriousness']
# Correctly aligned although to ['although', 'unfortunately', 'none', 'still', 'yet']
# Correctly aligned delegation to ['delegation', 'observer', 'ep', 'ambassador', 'parliaments']
# Incorrectly aligned foreign to ['boss', 'dealer', 'chinese', 'relocate', 'moldovan']
# Correctly aligned commission to ['commission', 'parliament', 'council', 'olaf', 'draft']
# Correctly aligned initiate to ['initiate', 'undertake', 'carry', 'launch', 'instigate']
# Correctly aligned use to ['use', 'distribute', 'pump', 'extract', 'reallocate']
# Correctly aligned immediately to ['immediately', 'swiftly', 'promptly', 'forthwith', 'accordingly']
# Correctly aligned renewable to ['renewable', 'biofuel', 'biomass', 'biogas', 'energy']
# Incorrectly aligned agricultural to ['arable', 'livestock', 'cotton', 'rum', 'processing']
# Incorrectly aligned grant to ['give', 'retain', 'remain', 'maintain', 'provide']
# Correctly aligned sensitive to ['sensitive', 'important', 'problematic', 'controversial', 'delicate']
# Correctly aligned proud to ['proud', 'pride', 'stand', 'wonderful', 'enjoy']
# Correctly aligned determine to ['determine', 'irrespective', 'correspond', 'i.e.', 'regardless']
# Correctly aligned spend to ['spend', 'allocate', 'earmark', 'disburse', 'invest']
# Incorrectly aligned pay to ['repay', 'pocket', 'earn', 'incur', 'reimburse']
# Correctly aligned day to ['day', 'weekend', 'week', 'month', 'saturday']
# Correctly aligned capacity to ['capacity', 'capability', 'infrastructure', 'potential', 'facility']
# Correctly aligned 20 to ['50', '20', '30', '10', '60']
# Correctly aligned confirm to ['confirm', 'indicate', 'publish', 'recall', 'notify']
# Correctly aligned population to ['population', 'people', 'inhabitant', 'woman', 'marginalise']
# Correctly aligned contribution to ['contribution', 'input', 'involvement', 'achievement', 'undoubtedly']
# Correctly aligned undoubtedly to ['undoubtedly', 'indeed', 'certainly', 'truly', 'extremely']
# Incorrectly aligned half to ['nearly', '80', '40', '90', '50']
# Correctly aligned competition to ['competition', 'deregulation', 'trade', 'protectionism', 'liberalisation']
# Correctly aligned growth to ['growth', 'competitiveness', 'economy', 'employment', 'productivity']
# Incorrectly aligned job to ['speaker', 'floor', 'broadcaster', 'minute', 'authorities']
# Correctly aligned competence to ['competence', 'competency', 'prerogative', 'responsibility', 'expertise']
# Correctly aligned secondly to ['secondly', 'thirdly', 'fourthly', 'firstly', 'lastly']
# Correctly aligned message to ['message', 'signal', 'voice', 'abundantly', 'gesture']
# Correctly aligned constant to ['constant', 'constantly', 'continually', 'continual', 'pointlessness']
# Correctly aligned speak to ['speak', 'miss', 'confine', 'hear', 'explain']
# Correctly aligned terrorist to ['terrorist', 'violent', 'terror', 'hizbollah', 'extremist']
# Correctly aligned fact to ['fact', 'divergence', 'difference', 'weakness', 'discrepancy']
# Correctly aligned mandate to ['mandate', 'treaties', 'formally', 'mission', 'credential']
# Correctly aligned wait to ['wait', 'stay', 'come', 'get', 'leave']
# Correctly aligned begin to ['start', 'begin', 'commence', 'beginning', 'underway']
# Correctly aligned morning to ['tomorrow', 'morning', 'evening', 'tonight', 'plenary']
# Correctly aligned therefore to ['therefore', 'nonetheless', 'naturally', 'consequently', 'nevertheless']
# Correctly aligned difficult to ['difficult', 'complex', 'challenging', 'complicated', 'demanding']
# Correctly aligned euro to ['2.8', 'gbp', 'eur', 'euro', 'usd']
# Correctly aligned pl to ['pl', '\xa0\xa0 ', 'nl', 'fi', 'ro']
# Correctly aligned door to ['door', 'slam', 'trick', 'floodgate', 'lock']
# Correctly aligned consequently to ['consequently', 'therefore', 'hence', 'essentially', 'primarily']
# Correctly aligned concept to ['approach', 'concept', 'strategy', 'policy', 'model']
# Correctly aligned currently to ['current', 'currently', 'new', 'similar', 'still']
# Incorrectly aligned record to ['admission', 'readmission', 'application', 'applicant', 'extension']
# Correctly aligned 2004 to ['2004', '2003', '2005', '2007', '2006']
# Correctly aligned belarus to ['belarus', 'georgia', 'taiwan', 'ukraine', 'cuba']
# Correctly aligned denmark to ['denmark', 'austria', 'sweden', 'finland', 'france']
# Correctly aligned israeli to ['israeli', 'angolan', 'sudanese', 'indonesian', 'syrian']
# Incorrectly aligned proof to ['evidence', 'rationally', 'fashion', 'strength', 'personality']
# Correctly aligned agency to ['agency', 'europol', 'olaf', 'eurojust', 'ombudsman']
# Correctly aligned trust to ['confidence', 'trust', 'ability', 'credibility', 'legitimacy']
# Correctly aligned together to ['common', 'joint', 'together', 'jointly', 'coherent']
# Incorrectly aligned drive to ['fly', 'travel', 'throw', 'walk', 'queue']
# Correctly aligned introduce to ['introduce', 'apply', 'introduction', 'abolish', 'standardise']
# Correctly aligned transparency to ['transparency', 'accountability', 'openness', 'clarity', 'consistency']
# Incorrectly aligned drug to ['medicine', 'medication', 'foodstuff', 'prescription', 'medicinal']
# Correctly aligned standard to ['standard', 'rule', 'norm', 'requirement', 'uniformly']
# Correctly aligned france to ['france', 'netherlands', 'germany', 'austria', 'italy']
# Correctly aligned article to ['article', 'articles', 'annex', 'paragraph', 'teu']
# Correctly aligned leave to ['stay', 'leave', 'return', 'dock', 'holiday']
# Incorrectly aligned balance to ['balanced', 'overall', 'comprehensive', 'consistent', 'sensible']
# Incorrectly aligned probably to ['none', 'indeed', 'really', 'think', 'nobody']
# Correctly aligned diversity to ['diversity', 'cultural', 'heritage', 'richness', 'linguistic']
# Correctly aligned bind to ['bind', 'mandatory', 'conform', 'harmonised', 'stringent']
# Incorrectly aligned business to ['economy', 'competitiveness', 'dynamic', 'economic', 'competitive']
# Correctly aligned decision to ['decision', 'judgment', 'judgement', 'legislator', 'procedure']
# Incorrectly aligned might to ['power', 'blackmail', 'unwillingness', 'stranglehold', 'warlord']
# Correctly aligned numerous to ['numerous', 'many', 'various', 'several', 'number']
# Correctly aligned ever to ['even', 'ever', 'relatively', 'less', 'least']
# Correctly aligned strengthen to ['strengthen', 'reinforce', 'enhance', 'consolidate', 'strengthening']
# Correctly aligned agriculture to ['agriculture', 'forestry', 'multifunctionality', 'multifunctional', 'agri']
# Correctly aligned cost to ['cost', 'expense', 'burden', 'incur', 'revenue']
# Correctly aligned evaluation to ['evaluation', 'assessment', 'analysis', 'appraisal', 'evaluate']
# Correctly aligned extensive to ['extensive', 'feasibility', 'technical', 'preparatory', 'thorough']
# Correctly aligned prepare to ['prepare', 'anticipate', 'start', 'present', 'cope']
# Correctly aligned justify to ['justify', 'justifiable', 'unacceptable', 'justification', 'imply']
# Correctly aligned know to ['know', 'discover', 'apparently', 'admit', 'tell']
# Correctly aligned however to ['however', 'nevertheless', 'certainly', 'nonetheless', 'obviously']
# Incorrectly aligned member to ['meps', 'members', 'delegation', 'nomination', 'observer']
# Correctly aligned damage to ['damage', 'harm', 'loss', 'inconvenience', 'strain']
# Correctly aligned 30 to ['50', '20', '30', '40', '60']
# Correctly aligned source to ['source', 'bio', 'generate', 'material', 'geological']
# Correctly aligned 2013 to ['2013', '2008', '2007', '2006', '2010']
# Correctly aligned argument to ['argument', 'reason', 'idea', 'objection', 'impression']
# Correctly aligned 5 to ['3', '5', '4', '2', '35']
# Correctly aligned attempt to ['try', 'seek', 'attempt', 'want', 'prepared']
# Correctly aligned negotiate to ['negotiate', 'negotiation', 'settle', 'decide', 'renegotiate']
# Correctly aligned public to ['public', 'private', 'national', 'domestic', 'corporate']
# Incorrectly aligned express to ['confirm', 'hear', 'explain', 'reiterate', 'discuss']
# Correctly aligned subsidiarity to ['subsidiarity', 'proportionality', 'principle', 'reciprocity', 'competence']
# Correctly aligned bilateral to ['bilateral', 'multilateral', 'mercosur', 'readmission', 'epa']
# Correctly aligned criticism to ['criticism', 'accusation', 'reservation', 'attitude', 'fact']
# Correctly aligned 1999 to ['1999', '1998', '2001', '2003', '1997']
# Incorrectly aligned date to ['datum', 'database', 'identification', 'information', 'documentation']
# Correctly aligned remember to ['remind', 'remember', 'recall', 'acknowledge', 'forget']
# Correctly aligned technological to ['technological', 'innovation', 'technology', 'potential', 'ict']
# Correctly aligned speaker to ['speaker', 'colleague', 'occasion', 'briefly', 'evening']
# Incorrectly aligned form to ['establish', 'define', 'set', 'construct', 'represent']
# Correctly aligned 15 to ['15', '25', '10', '27', '20']
# Incorrectly aligned traffic to ['transport', 'tourism', 'agriculture', 'energy', 'telecommunications']
# Correctly aligned invest to ['invest', 'investment', 'diversify', 'harness', 'r&d']
# Correctly aligned recognition to ['recognition', 'respect', 'acceptance', 'mutual', 'autonomy']
# Incorrectly aligned like to ['none', 'perhaps', 'seem', 'hardly', 'think']
# Correctly aligned kingdom to ['kingdom', 'germany', 'uk', 'ireland', 'sweden']
# Correctly aligned second to ['second', 'first', 'fourth', 'final', 'two']
# Incorrectly aligned run to ['materialise', 'come', 'push', 'foresee', 'appear']
# Correctly aligned namely to ['namely', 'one', 'precisely', 'another', 'essentially']
# Incorrectly aligned january to ['june', 'april', 'july', 'october', 'february']
# Incorrectly aligned wish to ['confident', 'hope', 'expect', 'succeed', 'proud']
# Correctly aligned realistic to ['realistic', 'sensible', 'ambitious', 'pragmatic', 'balanced']
# Correctly aligned adoption to ['adoption', 'adopt', 'revision', 'revise', 'approve']
# Correctly aligned reconstruction to ['reconstruction', 'rehabilitation', 'rebuilding', 'afghanistan', 'serbia']
# Correctly aligned accident to ['accident', 'shipwreck', 'injury', 'toulouse', 'fatal']
# Correctly aligned protection to ['protection', 'protect', 'safeguard', 'guarantee', 'safety']
# Correctly aligned appeal to ['urge', 'appeal', 'incumbent', 'call', 'plea']
# Correctly aligned national to ['national', 'supranational', 'respective', 'supervisory', 'local']
# Correctly aligned cyprus to ['cyprus', 'macedonia', 'malta', 'albania', 'croatia']
# Correctly aligned perhaps to ['perhaps', 'maybe', 'probably', 'exactly', 'think']
# Correctly aligned suggestion to ['proposal', 'recommendation', 'text', 'report', 'suggestion']
# Correctly aligned friend to ['friend', 'spaniard', 'czechs', 'friendship', 'compatriot']
# Correctly aligned million to ['million', 'billion', '000', 'approximately', '1000']
# Correctly aligned tradition to ['tradition', 'sensibility', 'religion', 'identity', 'individuality']
# Incorrectly aligned occupy to ['discuss', 'examine', 'deal', 'handle', 'connect']
# Correctly aligned please to ['please', 'shall', 'gladly', 'ask', 'kindly']
# Correctly aligned america to ['americans', 'usa', 'ally', 'america', 'japan']
# Correctly aligned special to ['particular', 'special', 'paramount', 'specific', 'utmost']
# Correctly aligned open to ['open', 'meaningful', 'simple', 'honest', 'transparent']
# Correctly aligned sometimes to ['sometimes', 'often', 'truth', 'usually', 'unpleasant']
# Correctly aligned polish to ['polish', 'dutch', 'french', 'italian', 'swiss']
# Correctly aligned worldwide to ['worldwide', 'global', 'globally', 'world', 'international']
# Correctly aligned clarify to ['reiterate', 'clarify', 'emphasise', 'stress', 'remind']
# Correctly aligned full to ['full', 'fully', 'clear', 'strong', 'substantial']
# Correctly aligned conflict to ['conflict', 'tension', 'confrontation', 'nagorno', 'escalation']
# Correctly aligned clear to ['clear', 'consistent', 'clearly', 'credible', 'precise']
# Correctly aligned submit to ['submit', 'prepare', 'present', 'finalise', 'adopt']
# Correctly aligned reality to ['reality', 'scenario', 'history', 'challenge', 'paradox']
# Incorrectly aligned back to ['daddy', 'overboard', 'dark', 'ridiculous', 'away']
# Correctly aligned truth to ['truth', 'dare', 'nonsense', 'pretend', 'never']
# Correctly aligned discrimination to ['discrimination', 'harassment', 'sexual', 'abortion', 'segregation']
# Correctly aligned guarantee to ['ensure', 'guarantee', 'safeguard', 'secure', 'maintenance']
# Correctly aligned normal to ['normal', 'equitable', 'automatically', 'ordinary', 'easy']
# Correctly aligned paragraph to ['paragraph', 'articles', 'recital', 'subparagraph', 'article']
# Correctly aligned effective to ['effective', 'effectively', 'necessary', 'ensure', 'efficient']
# Incorrectly aligned material to ['cadmium', 'nickel', 'phthalate', 'additive', 'pesticide']
# Correctly aligned 18 to ['18', '16', '14', '24', '12']
# Correctly aligned seat to ['seat', 'compose', 'headquarters', 'governing', 'administrator']
# Correctly aligned rich to ['rich', 'wealthy', 'industrialised', 'poor', 'developed']
# Correctly aligned daily to ['everyday', 'daily', 'lifetime', 'sick', 'countless']
# Correctly aligned internet to ['internet', 'download', 'video', 'interactive', 'online']
# Correctly aligned soon to ['soon', 'quickly', 'ready', 'rapidly', 'able']
# Correctly aligned affect to ['affected', 'assist', 'affect', 'various', 'local']
# Correctly aligned colleague to ['colleague', 'gratified', 'glad', 'hearten', 'unattached']
# Incorrectly aligned place to ['deal', 'address', 'arise', 'accounting', 'observe']
# Correctly aligned strategy to ['strategy', 'policy', 'approach', 'guideline', 'objective']
# Incorrectly aligned power to ['force', 'coalition', 'arsenal', 'part', 'path']
# Correctly aligned fr to ['fr', 'nl', 'pt', 'ro', 'pl']
# Incorrectly aligned track to ['pursue', 'coordinate', 'conduct', 'identify', 'align']
# Correctly aligned regime to ['dictator', 'dictatorship', 'regime', 'warlord', 'aggression']
# Correctly aligned die to ['die', 'kill', 'undernourished', 'starve', 'homeless']
# Incorrectly aligned yes to ['none', 'exactly', 'something', 'anything', 'perhaps']
# Correctly aligned consumer to ['consumer', 'customer', 'manufacturer', 'user', 'saver']
# Correctly aligned specific to ['specific', 'horizontal', 'complementary', 'sectoral', 'special']
# Correctly aligned difference to ['difference', 'discrepancy', 'disparity', 'imbalance', 'difficulty']
# Correctly aligned option to ['option', 'formula', 'element', 'objective', 'parameter']
# Correctly aligned romania to ['romania', 'malta', 'bulgaria', 'croatia', 'slovakia']
# Correctly aligned risk to ['risk', 'hazard', 'danger', 'strain', 'vulnerability']
# Correctly aligned discussion to ['debate', 'discussion', 'deliberation', 'consultation', 'negotiation']
# Incorrectly aligned arise to ['create', 'generate', 'exacerbate', 'gain', 'cope']
# Correctly aligned concrete to ['practical', 'concrete', 'specific', 'definite', 'precisely']
# Correctly aligned threaten to ['threaten', 'inflict', 'destabilise', 'plunge', 'endanger']
# Incorrectly aligned opposite to ['perceive', 'εu', 'perception', 'manifestly', 'condemnation']
# Incorrectly aligned waste to ['incineration', 'hazardous', 'landfill', 'transportation', 'hydrocarbon']
# Correctly aligned portugal to ['portugal', 'spain', 'greece', 'ireland', 'italy']
# Correctly aligned austria to ['austria', 'denmark', 'sweden', 'france', 'italy']
# Correctly aligned intention to ['intention', 'ambition', 'idea', 'attempt', 'position']
# Incorrectly aligned maintain to ['retain', 'adjust', 'introduce', 'abolish', 'limit']
# Correctly aligned 7 to ['7', '3', '6', '4', '2']
# Correctly aligned february to ['april', 'november', 'february', 'october', 'march']
# Correctly aligned action to ['action', 'project', 'initiative', 'programme', 'activity']
# Correctly aligned three to ['three', 'two', 'four', 'five', 'six']
# Correctly aligned poor to ['poor', 'wealthy', 'rich', 'underdeveloped', 'developed']
# Correctly aligned product to ['product', 'foodstuff', 'honey', 'manufacture', 'gm']
# Correctly aligned afternoon to ['afternoon', 'evening', 'morning', 'midday', 'thursday']
# Incorrectly aligned operation to ['factory', 'slaughterhouse', 'farm', 'company', 'relocate']
# Correctly aligned reform to ['reform', 'adjustment', 'consolidation', 'transformation', 'enlargement']
# Correctly aligned solidarity to ['solidarity', 'unity', 'democracy', 'integration', 'prosperity']
# Correctly aligned border to ['border', 'boundary', 'airspace', 'rubicon', 'fortress']
# Correctly aligned crime to ['crime', 'terrorism', 'perpetrator', 'criminality', 'atrocity']
# Incorrectly aligned make to ['carry', 'subsequent', 'adjust', 'envisage', 'evaluate']
# Correctly aligned alliance to ['alliance', 'greens', 'employers', 'pro', 'confederation']
# Correctly aligned bring to ['bring', 'come', 'turn', 'put', 'reach']
# Correctly aligned urgent to ['urgently', 'urgent', 'immediate', 'consequently', 'response']
# Correctly aligned mention to ['mention', 'refer', 'recall', 'remind', 'allude']
# Correctly aligned agreement to ['agreement', 'protocol', 'agreements', 'negotiation', 'chile']
# Correctly aligned definition to ['definition', 'harmonised', 'concept', 'labelling', 'formulation']
# Correctly aligned money to ['money', 'monie', 'coffer', 'funding', 'taxpayer']
# Correctly aligned july to ['april', 'november', 'july', 'october', 'february']
# Correctly aligned innovative to ['innovative', 'intelligent', 'creative', 'ict', 'entrepreneurship']
# Correctly aligned system to ['system', 'mechanism', 'arrangement', 'structure', 'scheme']
# Correctly aligned pt to ['pt', 'fr', 'pl', 'ro', '\xa0\xa0 ']
# Correctly aligned intervention to ['intervene', 'act', 'recourse', 'supervise', 'intervention']
# Correctly aligned destroy to ['destroy', 'ruin', 'liberate', 'wipe', 'blight']
# Correctly aligned particularly to ['particularly', 'especially', 'extremely', 'particular', 'obviously']
# Correctly aligned italian to ['italian', 'french', 'spanish', 'german', 'greek']
# Correctly aligned largely to ['largely', 'essentially', 'broad', 'ultimately', 'overall']
# Correctly aligned enjoy to ['enjoy', 'regain', 'deprive', 'uphold', 'live']
# Correctly aligned show to ['show', 'demonstrate', 'emerge', 'reflect', 'despite']
# Correctly aligned presidency to ['presidency', 'presidencies', 'barcelona', 'seville', 'laeken']
# Correctly aligned remain to ['remain', 'keep', 'never', 'sight', 'one']
# Correctly aligned convention to ['protocol', 'convention', 'conventions', 'agreement', 'marpol']
# Correctly aligned take to ['give', 'take', 'send', 'taking', 'assume']
# Correctly aligned ireland to ['ireland', 'germany', 'sweden', 'france', 'italy']
# Correctly aligned treat to ['discuss', 'treat', 'deal', 'handle', 'address']
# Incorrectly aligned floor to ['poison', 'rain', 'predator', 'sun', 'tank']
# Correctly aligned result to ['outcome', 'result', 'breakthrough', 'conclusion', 'das']
# Incorrectly aligned scope to ['extent', 'amount', 'quantity', 'volume', 'cost']
# Correctly aligned ban to ['ban', 'prohibition', 'prohibit', 'moratorium', 'banning']
# Correctly aligned french to ['french', 'german', 'dutch', 'italian', 'spanish']
# Correctly aligned evaluate to ['evaluate', 'assess', 'analysis', 'assessment', 'analyse']
# Incorrectly aligned construction to ['creation', 'integration', 'consolidate', 'strengthening', 'bolster']
# Correctly aligned 2008 to ['2008', '2009', '2006', '2007', '2004']
# Correctly aligned help to ['assistance', 'aid', 'funding', 'reconstruction', 'help']
# Correctly aligned communist to ['communist', 'fascist', 'nazi', 'totalitarian', 'nationalist']
# Correctly aligned advantage to ['benefit', 'advantage', 'potential', 'obstacle', 'investor']
# Correctly aligned impression to ['impression', 'feeling', 'fear', 'mistake', 'perception']
# Correctly aligned defend to ['defend', 'assert', 'uphold', 'affirm', 'champion']
# Correctly aligned dangerous to ['dangerous', 'harmful', 'harmless', 'susceptible', 'unhealthy']
# Correctly aligned analysis to ['analysis', 'appraisal', 'evaluation', 'assessment', 'analyse']
# Correctly aligned unfortunately to ['unfortunately', 'none', 'regrettably', 'still', 'sadly']
# Incorrectly aligned human to ['genotype', 'fertility', 'genetic', 'mankind', 'immeasurable']
# Incorrectly aligned afford to ['contribute', 'represent', 'valuable', 'accomplish', 'sustain']
# Correctly aligned model to ['model', 'concept', 'philosophy', 'structure', 'system']
# Incorrectly aligned legal to ['migrant', 'immigrant', 'repatriation', 'illegal', 'immigration']
# Correctly aligned overcome to ['overcome', 'surmount', 'resolve', 'solve', 'persist']
# Incorrectly aligned judge to ['call', 'address', 'insist', 'focus', 'prioritise']
# Correctly aligned process to ['process', 'negotiation', 'path', 'dialogue', 'reform']
# Correctly aligned access to ['access', 'affordable', 'guarantee', 'availability', 'healthcare']
# Correctly aligned sweden to ['sweden', 'denmark', 'finland', 'austria', 'germany']
# Incorrectly aligned policy to ['directive', 'regulation', 'directives', 'legislation', 'modification']
# Correctly aligned chinese to ['chinese', 'russian', 'vietnamese', 'cambodian', 'algerian']
# Correctly aligned 100 to ['100', '150', '50', '200', '30']
# Correctly aligned remark to ['remark', 'comment', 'briefly', 'point', 'speaker']
# Correctly aligned industry to ['industry', 'automotive', 'manufacturing', 'automobile', 'tourism']
# Correctly aligned expectation to ['expectation', 'aspiration', 'ambition', 'ability', 'demand']
# Correctly aligned independent to ['independent', 'body', 'individual', 'entity', 'independently']
# Incorrectly aligned lay to ['lie', 'correspond', 'define', 'set', 'relegate']
# Correctly aligned regulation to ['regulation', 'directive', 'directives', 'modification', 'eec']
# Correctly aligned billion to ['billion', 'million', 'bn', 'dollar', 'usd']
# Correctly aligned draft to ['draft', 'text', 'proposal', 'amend', 'entirety']
# Correctly aligned represent to ['constitute', 'create', 'perceive', 'represent', 'associate']
# Correctly aligned interesting to ['interesting', 'helpful', 'useful', 'informative', 'exciting']
# Correctly aligned per to ['per', '50', '60', '20', '30']
# Correctly aligned complex to ['complex', 'complicated', 'sensitive', 'complexity', 'delicate']
# Correctly aligned military to ['military', 'iraq', 'nato', 'diplomatic', 'hizbollah']
# Correctly aligned broad to ['broad', 'wide', 'meaningful', 'strong', 'genuine']
# Correctly aligned guideline to ['guideline', 'guidelines', 'strategy', 'methodology', 'indicator']
# Correctly aligned assembly to ['assembly', 'interparliamentary', 'parliamentary', 'credential', 'jpa']
# Correctly aligned aid to ['subsidy', 'aid', 'cofinancing', 'payment', 'premium']
# Incorrectly aligned sea to ['polluted', 'coastline', 'lake', 'beach', 'coast']
# Correctly aligned closely to ['close', 'enhanced', 'structured', 'respective', 'closely']
# Correctly aligned practice to ['practice', 'legislation', 'method', 'theory', 'law']
# Correctly aligned grow to ['grow', 'heighten', 'increase', 'decline', 'vulnerability']
# Correctly aligned expression to ['endorsement', 'backing', 'expression', 'emphatic', 'confirmation']
# Correctly aligned negative to ['negative', 'adverse', 'disastrous', 'damaging', 'detrimental']
# Correctly aligned value to ['value', 'belief', 'tolerance', 'destiny', 'bond']
# Correctly aligned status to ['status', 'mandate', 'autonomy', 'quo', 'circumstance']
# Correctly aligned impact to ['impact', 'repercussion', 'consequence', 'effect', 'implication']
# Correctly aligned equality to ['equality', 'mainstreaming', 'gender', 'empowerment', 'mainstreame']
# Correctly aligned republic to ['republic', 'montenegro', 'macedonia', 'albania', 'fyrom']
# Correctly aligned 3 to ['3', '4', '2', '5', '7']
# Correctly aligned mechanism to ['mechanism', 'instrument', 'tool', 'system', 'effective']
# Correctly aligned local to ['local', 'chiefly', 'regional', 'locally', 'various']
# Correctly aligned intensive to ['fruitful', 'intensively', 'intensive', 'constructive', 'constructively']
# Incorrectly aligned large to ['enormous', 'great', 'considerable', 'huge', 'major']
# Incorrectly aligned accordingly to ['appropriate', 'suitable', 'proper', 'adequate', 'relevant']
# Correctly aligned summit to ['summit', 'gothenburg', 'stockholm', 'laeken', 'thessaloniki']
# Correctly aligned march to ['march', 'november', 'october', 'february', 'december']
# Correctly aligned parliamentary to ['parliamentary', 'consultative', 'interparliamentary', 'codecision', 'jpa']
# Incorrectly aligned away to ['i.e.', 'whereby', '1', 'adjust', '2005']
# Correctly aligned today to ['today', 'glad', 'exactly', 'moment', 'none']
# Correctly aligned europe to ['europe', 'continent', 'world', 'europeans', 'prosperity']
# Correctly aligned expect to ['expect', 'confident', 'hope', 'demand', 'deliver']
# Correctly aligned india to ['india', 'china', 'brazil', 'opec', 'mexico']
# Incorrectly aligned complete to ['obligatory', 'thus', 'mandatory', 'compulsory', 'i.e.']
# Correctly aligned practical to ['practical', 'precisely', 'suitable', 'real', 'appropriate']
# Correctly aligned base to ['base', 'underpin', 'presuppose', 'guide', 'incompatible']
# Correctly aligned two to ['two', 'three', 'four', 'several', 'five']
# Correctly aligned detail to ['detailed', 'depth', 'detail', 'carefully', 'thoroughly']
# Incorrectly aligned finish to ['restart', 'unblock', 'prolong', 'reopen', 'sabotage']
# Correctly aligned research to ['research', 'innovation', 'renewable', 'r[amp]d', 'diversification']
# Incorrectly aligned demand to ['call', 'urge', 'incumbent', 'appeal', 'recommend']
# Incorrectly aligned consider to ['believe', 'obviously', 'think', 'certainly', 'nonetheless']
# Correctly aligned democracy to ['democracy', 'democratic', 'independence', 'democratisation', 'parliamentarianism']
# Correctly aligned network to ['network', 'networks', 'telecommunication', 'navigation', 'europass']
# Correctly aligned discharge to ['discharge', 'preliminary', 'assent', 'codecision', 'explanation']
# Correctly aligned conference to ['conference', 'ministerial', 'seminar', 'meeting', 'nairobi']
# Correctly aligned victim to ['victim', 'innocent', 'offender', 'perpetrator', 'survivor']
# Correctly aligned october to ['october', 'november', 'april', 'december', 'march']
# Correctly aligned 16 to ['16', '35', '36', '14', '32']
# Correctly aligned deadline to ['deadline', 'timeframe', 'timetable', 'timescale', 'period']
# Correctly aligned etc to ['etc', 'leisure', 'housing', 'maintenance', 'and/or']
# Incorrectly aligned liberal to ['socialist', 'liberals', 'csu', 'conservative', 'greens']
# Correctly aligned initiative to ['initiative', 'action', 'programme', 'measure', 'project']
# Correctly aligned sovereignty to ['sovereignty', 'sovereign', 'autonomy', 'integrity', 'independence']
# Correctly aligned moment to ['moment', 'thing', 'time', 'probably', 'perhaps']
# Correctly aligned official to ['official', 'staff', 'assistant', 'senior', 'administrator']
# Incorrectly aligned suspend to ['expose', 'escape', 'inflict', 'tolerate', 'abuse']
# Correctly aligned 25 to ['25', '15', '27', 'fifteen', '10']
# Correctly aligned sign to ['sign', 'ratify', 'signatory', 'signing', 'aarhus']
# Correctly aligned credibility to ['credibility', 'legitimacy', 'confidence', 'accountability', 'ever']
# Correctly aligned effect to ['effect', 'impact', 'consequence', 'risk', 'result']
# Correctly aligned succeed to ['succeed', 'hope', 'confident', 'successful', 'consensus']
# Correctly aligned palestine to ['palestine', 'lebanon', 'iraq', 'israel', 'syria']
# Correctly aligned serbia to ['serbia', 'kosovo', 'macedonia', 'albania', 'montenegro']
# Correctly aligned short to ['brief', 'finish', 'short', 'briefly', 'late']
# Correctly aligned withdraw to ['withdraw', 'reject', 'defer', 'reinstate', 'suspend']
# Correctly aligned request to ['urge', 'call', 'appeal', 'invite', 'request']
# Correctly aligned nation to ['nation', 'society', 'war', 'international', 'islamic']
# Incorrectly aligned correct to ['worthwhile', 'correctly', 'sensible', 'appropriate', 'exactly']
# Correctly aligned 000 to ['000', '1000', '500', 'million', '250']
# Correctly aligned finally to ['finally', 'firstly', 'lastly', 'secondly', 'thirdly']
# Correctly aligned already to ['already', 'recently', 'previously', 'early', 'yet']
# Correctly aligned thus to ['thus', 'ultimately', 'thereby', 'mean', 'making']
# Correctly aligned constitution to ['constitution', 'treaty', 'nice', 'referendum', 'treaties']
# Correctly aligned prevention to ['prevention', 'preventive', 'communicable', 'preparedness', 'preventative']
# Correctly aligned start to ['begin', 'beginning', 'start', 'precede', 'finish']
# Correctly aligned institution to ['institution', 'institutions', 'legitimacy', 'supranational', 'structure']
# Correctly aligned integrate to ['integrated', 'integrate', 'coherent', 'coordinated', 'complementary']
# Correctly aligned small to ['small', 'sized', 'relocate', 'manufacturing', 'sme']
# Correctly aligned animal to ['animal', 'infected', 'ruminant', 'bird', 'pet']
# Correctly aligned decade to ['decade', 'year', 'month', 'century', 'quarter']
# Correctly aligned speech to ['speech', 'hear', 'quotation', 'barroso', 'conversation']
# Correctly aligned restriction to ['restriction', 'exemption', 'imposition', 'derogation', 'relaxation']
# Correctly aligned tourism to ['tourism', 'agriculture', 'forestry', 'draftsman', 'agri']
# Correctly aligned debate to ['debate', 'discussion', 'deliberation', 'reflection', 'igc']
# Correctly aligned heart to ['heart', 'pride', 'whole', 'among', 'seriously']
# Correctly aligned obstacle to ['obstacle', 'barrier', 'impediment', 'hurdle', 'difficulty']
# Correctly aligned gender to ['gender', 'equality', 'woman', 'sexual', 'mainstreaming']
# Correctly aligned consequence to ['consequence', 'repercussion', 'impact', 'effect', 'implication']
# Incorrectly aligned employ to ['specialise', 'operate', 'recruit', 'specialist', 'manager']
# Correctly aligned develop to ['develop', 'evolve', 'build', 'transform', 'create']
# Correctly aligned recommend to ['recommend', 'propose', 'approve', 'suggest', 'call']
# Correctly aligned priority to ['priority', 'objective', 'goal', 'ambition', 'necessity']
# Correctly aligned future to ['future', 'whole', 'really', 'prospect', 'heart']
# Incorrectly aligned possibly to ['actually', 'might', 'could', 'yet', 'may']
# Correctly aligned create to ['create', 'build', 'provide', 'offer', 'acquire']
# Correctly aligned need to ['need', 'require', 'provide', 'importantly', 'enable']
# Correctly aligned opportunity to ['occasion', 'opportunity', 'sincere', 'finally', 'lesson']
# Incorrectly aligned observe to ['witness', 'deteriorate', 'react', 'hold', 'show']
# Correctly aligned european to ['european', 'supranational', 'within', 'entire', 'whole']
# Correctly aligned referendum to ['referendum', 'referenda', 'voter', 'election', 'electorate']
# Correctly aligned 2006 to ['2006', '2003', '2007', '2008', '2005']
# Correctly aligned east to ['east', 'africa', 'caucasus', 'north', 'ages']
# Correctly aligned prove to ['prove', 'seem', 'become', 'intentione', 'conceive']
# Correctly aligned mistake to ['mistake', 'error', 'failing', 'anomaly', 'pitfall']
# Correctly aligned approve to ['approve', 'adopt', 'reject', 'amend', 'recommend']
# Correctly aligned ii to ['ii', 'iii', 'basel', 'iv', 'sis']
# Correctly aligned russian to ['russian', 'chinese', 'georgian', 'pakistani', 'moldovan']
# Correctly aligned global to ['global', 'worldwide', 'multilateral', 'cohesive', 'international']
# Correctly aligned document to ['document', 'text', 'website', 'recommendation', 'documentation']
# Correctly aligned delay to ['delay', 'irregularity', 'haste', 'backlog', 'litigation']
# Correctly aligned nato to ['nato', 'usa', 'russia', 'iraq', 'military']
# Correctly aligned nl to ['nl', 'pl', 'fi', '\xa0\xa0 \xa0', 'es']
# Correctly aligned journalist to ['journalist', 'imprison', 'jail', 'editor', 'dissident']
# Correctly aligned interinstitutional to ['interinstitutional', 'enhanced', 'formal', 'formalise', 'aforementioned']
# Correctly aligned employee to ['worker', 'employee', 'employer', 'workforce', 'workplace']
# Correctly aligned thursday to ['thursday', 'wednesday', 'monday', 'friday', 'coreper']
# Correctly aligned production to ['production', 'cultivation', 'crop', 'manufacturing', 'hemp']
# Correctly aligned also to ['also', 'naturally', 'particularly', 'particular', 'strongly']
# Correctly aligned staff to ['staff', 'personnel', 'manager', 'specialist', 'manpower']
# Incorrectly aligned check to ['examine', 'evaluate', 'verify', 'analyse', 'assess']
# Correctly aligned pressure to ['pressure', 'temptation', 'power', 'opposition', 'influence']
# Correctly aligned plan to ['plan', 'strategy', 'programme', 'initiative', 'project']
# Incorrectly aligned get to ['communicate', 'assume', 'convey', 'acquire', 'distinguish']
# Incorrectly aligned choice to ['election', 'presidential', 'referendum', 'electoral', 'elect']
# Correctly aligned eye to ['europe', 'eye', 'blind', 'seriously', 'mind']
# Correctly aligned significant to ['significant', 'important', 'crucial', 'key', 'essential']
# Correctly aligned effort to ['effort', 'endeavour', 'engagement', 'commitment', 'cooperation']
# Incorrectly aligned secure to ['safe', 'good', 'perfect', 'reasonably', 'safely']
# Correctly aligned exchange to ['networking', 'dissemination', 'structured', 'disseminate', 'exchange']
# Incorrectly aligned transport to ['transportation', 'pollute', 'spray', 'cleaning', 'liquid']
# Correctly aligned century to ['century', 'decade', 'era', 'legacy', 'davos']
# Correctly aligned deficit to ['deficit', 'rigidity', 'inflation', 'disparity', 'cost']
# Correctly aligned application to ['application', 'compliance', 'transposition', 'implement', 'conformity']
# ...
# Correctly aligned visit to ['visit', 'ambassador', 'troika', 'trip', 'ababa']
# Correctly aligned african to ['african', 'maghreb', 'pacific', 'neighbouring', 'caribbean']
# Correctly aligned independence to ['independence', 'autonomy', 'sovereignty', 'neutrality', 'democratic']
# Correctly aligned outside to ['outside', 'inside', 'within', 'throughout', 'across']
# Correctly aligned accordance to ['accordance', 'basis', 'agree', 'respect', 'clearly']
# Correctly aligned bad to ['bad', 'inferior', 'well', 'dubious', 'hardly']
# Incorrectly aligned central to ['key', 'main', 'crucial', 'vital', 'major']
# Correctly aligned ratification to ['ratification', 'ratify', 'signing', 'nice', 'accession']
# Correctly aligned refer to ['refer', 'acknowledge', 'highlight', 'address', 'include']
# Correctly aligned china to ['china', 'india', 'russia', 'brazil', 'opec']
# Correctly aligned repeat to ['repeat', 'say', 'reiterate', 'remind', 'recall']
# Correctly aligned necessary to ['necessary', 'appropriate', 'effective', 'importantly', 'need']
# Correctly aligned unacceptable to ['unacceptable', 'absurd', 'inappropriate', 'irresponsible', 'disgraceful']
# Incorrectly aligned battle to ['fight', 'combating', 'combat', 'scourge', 'fighting']
# Correctly aligned yesterday to ['yesterday', 'morning', 'afternoon', 'dinner', 'sorry']
# Correctly aligned sensible to ['useful', 'sensible', 'appropriate', 'desirable', 'necessary']
# Correctly aligned define to ['define', 'distinguish', 'establish', 'apply', 'determine']
# Correctly aligned conviction to ['belief', 'faith', 'ideal', 'conviction', 'aspiration']
# Incorrectly aligned certainly to ['certain', 'specific', 'various', 'individual', 'hitherto']
# Correctly aligned emission to ['co2', 'carbon', 'dioxide', 'pollutant', 'emission']
# Correctly aligned statistic to ['statistic', 'survey', 'statistical', 'indicator', 'comparison']
# Incorrectly aligned death to ['rapist', 'massacre', 'jews', 'physically', 'mistreat']
# Correctly aligned president to ['president', 'lt', 'sl', 'juncker', 'sócrates']
# Correctly aligned 6 to ['6', '3', '4', '2', '7']
# Incorrectly aligned fall to ['assign', 'ignore', 'cover', 'apply', 'transpose']
# Incorrectly aligned enter to ['raise', 'address', 'discuss', 'refer', 'highlight']
# Correctly aligned answer to ['answer', 'response', 'reply', 'overview', 'insight']
# Correctly aligned low to ['low', 'decrease', 'lower', 'index', 'average']
# Incorrectly aligned relation to ['regard', 'relate', 'concern', 'include', 'pertain']
# Correctly aligned complaint to ['complaint', 'petition', 'petitioner', 'file', 'documentation']
# Correctly aligned afghanistan to ['afghanistan', 'iraq', 'darfur', 'sudan', 'burundi']
# Incorrectly aligned notice to ['indicate', 'recall', 'acknowledge', 'observe', 'confirm']
# Correctly aligned stability to ['stability', 'consolidation', 'prosperity', 'equilibrium', 'stable']
# Correctly aligned commissioner to ['commissioner', 'prodi', 'frattini', 'barroso', 'olli']
# Correctly aligned peace to ['peace', 'peaceful', 'reconciliation', 'harmony', 'rapprochement']
# Correctly aligned find to ['find', 'reach', 'draw', 'provide', 'obtain']
# Correctly aligned report to ['report', 'rapporteur', 'recommendation', 'böge', 'suggestion']
# Correctly aligned hand to ['hand', 'trick', 'monopoly', 'power', 'game']
# Correctly aligned development to ['development', 'diversification', 'expansion', 'growth', 'develop']
# Correctly aligned amount to ['sum', 'amount', 'appropriation', 'percentage', 'expenditure']
# Correctly aligned point to ['point', 'aspect', 'topic', 'element', 'theme']
# Correctly aligned six to ['five', 'six', 'four', 'eight', 'seven']
# Correctly aligned relate to ['pertain', 'relate', 'include', 'regard', 'refer']
# Correctly aligned responsible to ['responsible', 'competent', 'oversee', 'instruct', 'relevant']
# Correctly aligned task to ['task', 'challenge', 'responsibility', 'endeavour', 'function']
# Correctly aligned free to ['free', 'freedom', 'universal', 'fair', 'decent']
# Incorrectly aligned constantly to ['preparation', 'ongoing', 'subsequent', 'preparatory', 'commence']
# Correctly aligned attention to ['attention', 'importance', 'significance', 'prominence', 'consideration']
# Correctly aligned write to ['write', 'letter', 'interview', 'yesterday', 'quote']
# Correctly aligned deep to ['profound', 'deep', 'deeply', 'profoundly', 'unprecedented']
# Correctly aligned negotiation to ['negotiation', 'discussion', 'agreement', 'epa', 'dialogue']
# Correctly aligned extremely to ['extremely', 'highly', 'particularly', 'incredibly', 'extraordinarily']
# Correctly aligned text to ['text', 'wording', 'version', 'amendment', 'compromise']
# Correctly aligned challenge to ['challenge', 'problem', 'task', 'phenomenon', 'dilemma']
# Correctly aligned first to ['first', 'second', 'final', 'next', 'fourth']
# Correctly aligned avoid to ['avoid', 'minimise', 'eliminate', 'prevent', 'entail']
# Correctly aligned discuss to ['discuss', 'debate', 'discussion', 'examine', 'present']
# Correctly aligned generation to ['generation', 'century', 'life', 'planet', 'bright']
# Correctly aligned serious to ['seriousness', 'serious', 'seriously', 'gravity', 'lightly']
# Correctly aligned april to ['april', 'november', 'october', 'february', 'july']
# Correctly aligned situation to ['situation', 'circumstance', 'scenario', 'problem', 'consequence']
# Correctly aligned threat to ['threat', 'danger', 'phenomenon', 'phenomena', 'attack']
# Correctly aligned fear to ['fear', 'myth', 'stir', 'populism', 'despair']
# Correctly aligned version to ['version', 'text', 'wording', 'recital', 'annexe']
# Correctly aligned ship to ['ship', 'tanker', 'cargo', 'container', 'loading']
# Correctly aligned good to ['good', 'well', 'perfect', 'easy', 'exemplary']
# Correctly aligned reach to ['reach', 'arrive', 'bring', 'obtain', 'come']
# Correctly aligned extreme to ['extreme', 'accentuate', 'doubly', 'rife', 'topography']
# Incorrectly aligned close to ['conclude', 'enter', 'begin', 'start', 'align']
# Correctly aligned unanimously to ['unanimously', 'unanimous', 'entirety', 'plenary', 'council']
# Correctly aligned hour to ['hour', 'night', 'minute', 'month', 'clock']
# Correctly aligned implement to ['implement', 'transpose', 'comply', 'devise', 'revise']
# Correctly aligned external to ['external', 'decentralised', 'staffing', 'management', 'decentralise']
# Correctly aligned belgium to ['belgium', 'denmark', 'france', 'spain', 'italy']
# Correctly aligned freedom to ['freedom', 'justice', 'plurality', 'democracy', 'independence']
# Correctly aligned german to ['german', 'french', 'dutch', 'italian', 'belgian']
# Correctly aligned 13 to ['16', '13', '14', '6', '18']
# Correctly aligned croatia to ['croatia', 'macedonia', 'albania', 'turkey', 'slovenia']
# Correctly aligned prosperity to ['prosperity', 'prosperous', 'vitality', 'harmony', 'dynamism']
# Correctly aligned compromise to ['compromise', 'consensus', 'solution', 'text', 'conciliation']
# Incorrectly aligned lady to ['\xa0\xa0 ', 'president', 'sl', 'lt', 'pl']
# Incorrectly aligned essential to ['essentially', 'basically', 'namely', 'largely', 'precisely']
# Incorrectly aligned advice to ['council', 'commission', 'parliament', 'ecofin', 'presidency']
# Correctly aligned actually to ['actually', 'real', 'unless', 'thus', 'quickly']
# Correctly aligned basis to ['basis', 'base', 'foundation', 'framework', 'precondition']
# Incorrectly aligned carry to ['depend', 'demonstrate', 'implement', 'reflect', 'show']
# Correctly aligned element to ['element', 'aspect', 'component', 'feature', 'factor']
# Correctly aligned objective to ['objective', 'goal', 'guideline', 'target', 'strategy']
# Correctly aligned italy to ['italy', 'austria', 'france', 'germany', 'spain']
# Correctly aligned someone to ['someone', 'anybody', 'nobody', 'somebody', 'anyone']
# Incorrectly aligned de to ['kahn', 'brown', 'simon', 'anderson', 'hans']
# Correctly aligned late to ['later', 'afterwards', 'early', 'late', 'maybe']
# Correctly aligned appropriate to ['adequate', 'appropriate', 'optimum', 'proper', 'suitable']
# Correctly aligned sufficient to ['sufficient', 'adequate', 'insufficient', 'optimum', 'appropriate']
# Correctly aligned corruption to ['corruption', 'nepotism', 'mismanagement', 'crime', 'fraud']
# Correctly aligned traditional to ['traditional', 'traditionally', 'cultivate', 'speciality', 'geographic']
# Correctly aligned next to ['next', 'last', 'coming', 'later', 'first']
# Correctly aligned greek to ['greek', 'italian', 'spanish', 'portuguese', 'belgian']
# Correctly aligned explain to ['explain', 'tell', 'confirm', 'declare', 'say']
# Correctly aligned el to ['el', 'kozlov', 'lahoud', 'smirnov', 'talabani']
# Incorrectly aligned consist to ['constitute', 'define', 'remain', 'lie', 'restrict']
# Correctly aligned farmer to ['farmer', 'grower', 'farm', 'breeder', 'producer']
# Correctly aligned payment to ['payment', 'compensation', 'receipt', 'repayment', 'revenue']
# Correctly aligned build to ['construct', 'build', 'unify', 'erect', 'create']
# Correctly aligned allow to ['permit', 'allow', 'like', 'connection', 'wish']
# Correctly aligned agree to ['endorse', 'reject', 'approve', 'accept', 'agree']
# Correctly aligned people to ['nation', 'people', 'citizen', 'unity', 'europeans']
# Correctly aligned transparent to ['transparent', 'comprehensible', 'efficient', 'streamlined', 'credible']
# Correctly aligned reduction to ['reduction', 'reduce', 'increase', 'decrease', 'offset']
# Correctly aligned private to ['private', 'banking', 'broadcaster', 'intermediary', 'privatise']
# Incorrectly aligned mission to ['enrichment', 'antiviral', 'stockpile', 'deployment', 'disarmament']
# Correctly aligned education to ['education', 'vocational', 'training', 'educational', 'lifelong']
# Correctly aligned implementation to ['implementation', 'implement', 'adaptation', 'transposition', 'update']
# Correctly aligned inform to ['inform', 'communicate', 'consult', 'verify', 'investigate']
# Correctly aligned control to ['control', 'supervision', 'surveillance', 'monitoring', 'scrutiny']
# Correctly aligned alone to ['alone', 'hand', 'another', 'none', 'one']
# Correctly aligned world to ['world', 'continent', 'europe', 'planet', 'prosperous']
# Correctly aligned improvement to ['improvement', 'improve', 'improved', 'enhance', 'advance']
# Correctly aligned november to ['november', 'october', 'april', 'december', 'february']
# Correctly aligned eu to ['eu', 'union', 'europe', 'community', 'country']
# Correctly aligned europol to ['europol', 'eurojust', 'olaf', 'agency', 'judicial']
# Incorrectly aligned feature to ['provide', 'possess', 'acquire', 'pool', 'equip']
# Correctly aligned despite to ['despite', 'spite', 'notwithstanding', 'persist', 'show']
# Correctly aligned decide to ['decide', 'choose', 'determine', 'independently', 'stand']
# Incorrectly aligned provision to ['provide', 'availability', 'micro', 'adequate', 'additional']
# Incorrectly aligned state to ['direct', 'banking', 'prudential', 'abet', 'private']
# Correctly aligned resource to ['resource', 'capacity', 'wealth', 'infrastructure', 'scarce']
# Correctly aligned interested to ['involve', 'involved', 'interested', 'collaborate', 'concerned']
# Correctly aligned patten to ['patten', 'michel', 'nielson', 'lamy', 'waldner']
# Correctly aligned different to ['various', 'different', 'respective', 'diverse', 'certain']
# Correctly aligned goal to ['objective', 'goal', 'target', 'ambition', 'aim']
# Correctly aligned achieve to ['achieve', 'reach', 'bring', 'attain', 'obtain']
# Correctly aligned join to ['accede', 'join', 'enlarge', 'membership', 'applicant']
# Incorrectly aligned urge to ['push', 'insist', 'persuade', 'intervene', 'stand']
# Correctly aligned duty to ['duty', 'obligation', 'oblige', 'responsibility', 'must']
# Correctly aligned police to ['police', 'officer', 'magistrate', 'prosecution', 'judiciary']
# Correctly aligned encourage to ['encourage', 'assist', 'urge', 'help', 'persuade']
# Correctly aligned either to ['either', 'easily', 'automatically', 'refuse', 'instead']
# Correctly aligned statute to ['statute', 'treaty', 'treaties', 'constitution', 'text']
# Correctly aligned community to ['community', 'eu', 'union', 'state', 'international']
# Correctly aligned firmly to ['firmly', 'whilst', 'full', 'rightly', 'european']
# Correctly aligned end to ['end', 'beginning', 'autumn', 'shortly', 'later']
# Correctly aligned accept to ['accept', 'reject', 'acceptable', 'opt', 'oppose']
# Correctly aligned membership to ['membership', 'accession', 'candidate', 'join', 'accede']
# Correctly aligned profit to ['profit', 'profitability', 'windfall', 'turnover', 'revenue']
# Correctly aligned barroso to ['barroso', 'prodi', 'schüssel', 'sarkozy', 'borrell']
# Correctly aligned lack to ['lack', 'insufficient', 'inverse', 'considerable', 'constant']
# Correctly aligned minority to ['minority', 'nationality', 'roma', 'ethnic', 'christians']
# Correctly aligned forget to ['forget', 'remember', 'overlook', 'remind', 'neglect']
# Correctly aligned fair to ['fair', 'equitable', 'transparent', 'reciprocal', 'free']
# Correctly aligned say to ['say', 'tell', 'hear', 'explain', 'speak']
# Correctly aligned quality to ['quality', 'accessibility', 'reliability', 'comparability', 'efficacy']
# Correctly aligned opinion to ['believe', 'feel', 'think', 'opinion', 'obviously']
# Correctly aligned spanish to ['spanish', 'italian', 'french', 'greek', 'belgian']
# Correctly aligned give to ['give', 'come', 'provide', 'offer', 'gain']
# Incorrectly aligned design to ['transparent', 'efficient', 'devise', 'modernise', 'enable']
# Correctly aligned partner to ['partner', 'neighbour', 'relationship', 'actor', 'engagement']
# Incorrectly aligned considerably to ['considerable', 'significant', 'substantial', 'enormous', 'huge']
# Correctly aligned happen to ['happen', 'get', 'talk', 'come', 'wait']
# Correctly aligned cuba to ['cuba', 'taiwan', 'burma', 'zimbabwe', 'belarus']
# Correctly aligned refugee to ['refugee', 'displace', 'libya', 'idp', 'immigrant']
# Incorrectly aligned advance to ['consolidate', 'accelerate', 'relaunch', 'encourage', 'intensify']
# Correctly aligned instead to ['instead', 'rather', 'stop', 'simply', 'excuse']
# Correctly aligned ready to ['prepared', 'willing', 'ready', 'try', 'intend']
# Correctly aligned cohesion to ['cohesion', 'prosperity', 'sustainability', 'dimension', 'integration']
# Incorrectly aligned distribution to ['dissemination', 'bio', 'pornographic', 'encryption', 'precursor']
# Correctly aligned ten to ['ten', 'twelve', 'five', 'seven', 'eight']
# Incorrectly aligned include to ['really', 'also', 'ought', 'certainly', 'might']
# Incorrectly aligned view to ['balance', 'reason', 'viewpoint', 'seem', 'believe']
# Correctly aligned poland to ['poland', 'austria', 'germany', 'hungary', 'italy']
# Correctly aligned position to ['position', 'stance', 'approach', 'recommendation', 'compromise']
# Incorrectly aligned meet to ['arrange', 'hold', 'decide', 'determine', 'attend']
# Correctly aligned regional to ['regional', 'local', 'chiefly', 'inter', 'bi']
# Incorrectly aligned proceed to ['act', 'action', 'approach', 'reaction', 'stance']
# Correctly aligned irish to ['irish', 'spanish', 'belgian', 'french', 'greek']
# Correctly aligned fight to ['eradicate', 'combat', 'fight', 'counteract', 'scourge']
# Correctly aligned current to ['current', 'analyse', 'timing', 'precise', 'detailed']
# Correctly aligned chance to ['chance', 'opportunity', 'momentum', 'impetus', 'prospect']
# Correctly aligned creation to ['creation', 'establishment', 'strengthen', 'create', 'consolidate']
# Incorrectly aligned movement to ['nationalism', 'hatred', 'elite', 'fundamentalism', 'rivalry']
# Correctly aligned commit to ['commit', 'bind', 'obligation', 'oblige', 'comply']
# Incorrectly aligned legally to ['legal', 'procedural', 'contractual', 'ethical', 'statutory']
# Correctly aligned measure to ['measure', 'action', 'initiative', 'instrument', 'programme']
# Correctly aligned cooperation to ['cooperation', 'collaboration', 'coordination', 'synergy', 'dialogue']
# Correctly aligned woman to ['mainstreame', 'lifelong', 'woman', 'motherhood', 'man']
# Top 5 accuracy: 0.824

# %%
path = os.path.join('words', 'german_top_1000_translated.txt')
with open(path, 'r') as f:
    german_top_1000_translated = f.read().splitlines()
# find duplicates
words = set()
for item in german_top_1000_translated:
    if item in words:
        print(item)
    words.add(item)
# Out:
# support
# already
# area
# opinion
# committee
# president
# necessary
# however
# first
# therefore
# future
# commissioner
# opinion
# company
# regulation
# even
# work
# financial support
# clearly
# finally
# represent
# need
# first
# regarding
# full
# first
# different
# actually
# currently
# regulation
# difficult
# person
# rapporteur
# place
# only
# agreement
# condition
# today
# position
# special
# matter
# ask
# time
# help
# close
# notice
# effort
# application
# take place
# apply
# because of
# many
# united
# certainly
# currently
# express
# opinion
# agreement
# just
# principle
# measure
# in total
# receive
# knowledge
# task
# even
# approach
# agree
# even
# finally
# step
# consider
# together
# danger
# service
# recognize
# demand
# always
# decision
# use
# change
# wish
# complete
# responsibility
# connection
# location
# strengthen
# execution
# third
# past
# meeting
# need
# use
# absolutely
# absolutely
# Presidency
# hope
# need
# agreement
# decision
# view
# long
# finally
# experience
# fact
# participate
# significant
# determination
# responsible
# at the same time
# opposite
# relationship
# grant
# provide
# result
# regard
# attempt
# allow
# high
# force
